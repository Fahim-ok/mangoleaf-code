# %%
import matplotlib.pyplot as plt

# Assuming you have accuracy data for each model stored in lists
model_names = ["ConvNeXtLarge", "ConvNeXtBase", "InceptionResnetV2L", "VGG16", "Improved SwinV2", "Coatnet", "ResMLP", "WaveVisionNet"]
accuracy_data = [
    [0.1967,0.1987,0.2827,0.3340 , 0.3547, 0.4400, 0.5200, 0.5953, 0.6007,0.6593, 0.6627,0.6760, 0.7060,0.7500,0.7320 , 0.7493, 0.7880, 0.8060, 0.8033, 0.8147 , 0.8293, 0.8300,0.8520, 0.8247, 0.8487, 0.8393, 0.8353,0.8573, 0.8227, 0.84],
    [0.1093, 0.2220, 0.2333, 0.3233, 0.3727, 0.4160,0.4700,0.5240,0.5620, 0.6080, 0.6467, 0.6727, 0.7007,0.7240, 0.7413,0.7460, 0.7827,0.7667, 0.7813,0.8153,  0.8240,  0.8160, 0.8200,0.8253, 0.8467, 0.8440, 0.8420,0.8620, 0.8540,0.8540],
    [0.2193, 0.2293,  0.3140, 0.3747 , 0.4420, 0.5047 ,0.5793, 0.6547,0.6807,0.7000, 0.6177, 0.6447, 0.7707,0.7240, 0.7013,0.7160, 0.7327,0.7567, 0.7913,0.8153,  0.8030,  0.8160, 0.8100,0.8253, 0.8467, 0.8440, 0.8420,0.8620, 0.8540,0.8540 ],
    [0.2393, 0.3240 , 0.3747 , 0.4420 ,  0.5047, 0.5793 , 0.6547, 0.7000, 0.6807 , 0.6967, 0.7440 , 0.7647, 0.7427,0.7580, 0.7993, 0.7807,0.7753 , 0.7453, 0.8293, 0.8180,0.8347, 0.8127, 0.8420 , 0.8127,0.8422, 0.8027, 0.8152, 0.8347,0.8227,0.8527 ],
    [0.5635,  0.5121 , 0.8036 , 0.7569 , 0.5976,  0.7447 , 0.8814 ,0.8411, 0.7716  , 0.6436, 0.92730 , 0.9073, 0.9026 ,0.8997,0.9057, 0.8803,0.8654  ,  0.8709, 0.9339, 0.8680,0.8347, 0.8227, 0.8420 , 0.8127,0.9027, 0.8027, 0.8152, 0.8347,0.8227,0.9427 ],
    [0.5635,  0.5221 , 0.8236 , 0.7369 , 0.5576,  0.7347 , 0.8514 ,0.8311, 0.7416  , 0.6236, 0.92730 , 0.9373, 0.9126 ,0.8497,0.9157, 0.8603,0.8554  ,  0.8809, 0.9039, 0.8280,0.8147, 0.8527, 0.8220 , 0.8427,0.8227, 0.7527, 0.8052, 0.8147,0.8237,0.9127],
    [0.4786, 0.5914, 0.6508,0.7227, 0.6586 , 0.7583,0.8082 , 0.8236, 0.92010, 0.9154, 0.9471,0.9101, 0.9466, 0.93, 0.9507, 0.9578, 0.9555, 0.9584 , 0.9590 , 0.9602, 0.85, 0.9072 , 0.80, 0.82, 0.9272 , 0.87, 0.88, 0.90, 0.92, 0.94, 0.9572 ],
    [0.6063,  0.5042,  0.7862 ,0.3628, 0.9044 , 0.6490,0.8575 , 0.8670, 0.8450,0.7833, 0.9685 ,0.9697,0.9727, 0.9697, 0.9507, 0.9745, 0.9555, 0.9709 , 0.9762 , 0.9721, 0.9721, 0.9751 , 0.9715,0.9727, 0.9272 , 0.9727, 0.9711, 0.972191, 0.9711, 0.9731,0.9621]
]

# Create a plot for each model's accuracy with custom styles
styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-', 'k-', 'b--']
for i in range(len(model_names)):
    plt.plot(range(1, 31), accuracy_data[i][:30], styles[i], label=model_names[i], linewidth=2)

# Set labels and title
plt.xlabel('Epochs')
plt.ylabel('ACC Values')
plt.title('Loss Curves for 8 Models')
plt.legend(loc='lower right')
plt.grid(True)

# Add a background grid
plt.grid(linestyle='--', alpha=0.7)

# Add a legend with a shadow and frame
legend = plt.legend(frameon=True, shadow=True)
frame = legend.get_frame()
frame.set_facecolor('lightgray')

# Customize the axis ticks
plt.xticks(range(0, 31, 5))
plt.yticks([0.7, 0.8, 0.9, 1.0], labels=['20%', '40%', '80%', '100%'])

# Add a background color to the plot
plt.gca().set_facecolor('whitesmoke')

# Adjust the figure size
plt.gcf().set_size_inches(10, 6)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have loss data for each model stored in lists
model_names = ["ConvNeXtBase", "ConvNeXtLarge", "EfficientNetV2L", "InceptionResNetV2", "ResNet152", "NasNet", "Proposed", "NewModel"]

loss_data = [
    [4.8470, 4.4064, 4.1217, 4.0502, 3.9700, 4.0140, 3.8759, 3.8759, 3.8442, 3.7500, 3.7500, 3.7500, 3.7500, 3.6936, 3.6936, 3.6936, 3.6879, 3.6879, 3.5913, 3.5432, 3.5723, 3.5510, 3.4728, 3.4728, 3.4538, 3.4771, 3.3610, 3.3610, 3.3638, 3.3638, 3.3647, 3.3728, 3.2406, 3.3128, 3.2895, 3.2623, 3.2623, 3.2516, 3.2338, 3.1326, 3.1280, 3.1584, 3.0951, 3.0597, 3.0512, 3.0168, 2.9756, 2.9756, 2.9756, 2.9756],
    [3.0691, 2.8622, 2.8907, 2.4208, 2.2881, 2.1980, 2.2679, 2.1545, 2.0941, 2.1070, 2.0632, 2.0948, 2.0414, 2.1612, 2.1612, 2.0986, 2.0830, 2.0830, 1.9955, 2.0054, 1.9997, 2.0149, 1.9840, 1.9863, 1.9542, 1.9299, 1.9391, 1.9217, 1.9456, 1.9373, 1.9045, 1.8914, 1.8790, 1.8784, 1.8845, 1.8818, 1.8687, 1.8809, 1.8207, 1.8459, 1.8686, 3.1584, 1.8547, 1.9015, 1.8168, 1.7740, 1.7551, 1.7474, 1.7263, 1.7384],
    [2.5131, 2.4412, 2.3641, 2.3033, 2.2461, 2.1707, 2.1231, 2.0446, 1.9991, 1.9991, 1.9330, 1.9365, 1.9248, 1.9248, 1.9012, 1.8548, 1.8451, 1.8451, 1.8351, 1.9013, 1.9013, 1.8105, 1.8217, 1.8066, 1.7914, 1.7667, 1.7658, 1.7658, 1.7429, 1.7183, 1.6757, 1.7278, 1.6947, 1.6880, 1.6762, 1.6547, 1.6508, 3.2516, 3.2338, 3.1326, 3.1280, 3.1584, 3.0951, 3.0597, 3.0512, 3.0168, 2.9756, 2.9756, 2.9756, 2.9756],
    [2.7368, 2.7368, 2.6488, 2.5805, 2.5805, 2.5110, 2.4589, 2.4589, 2.4589, 2.4521, 2.4217, 2.4047, 2.3453, 2.2832, 2.3236, 2.2653, 2.3049, 2.2353, 2.2469, 2.2762, 2.2209, 2.1777, 2.2054, 2.1424, 2.1571, 2.1079, 2.1079, 2.1399, 2.1060, 2.0905, 2.0444, 2.0835, 2.0452, 2.1216, 2.0856, 2.0887, 3.2623, 2.0212, 1.9830, 1.9954, 2.003, 2.0540, 2.0403, 1.9663, 1.9824, 1.9684, 2.0403, 2.0403, 2.0039, 2.0039],
    [3.1341, 3.1341, 2.7940, 2.7940, 2.7428, 2.7428, 2.6796, 2.6796, 2.6798, 2.6798, 2.6130, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5071, 2.5071, 2.4845, 2.4402, 2.5203, 2.4402, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.9756, 2.9756, 2.9756],
    [3.2584, 3.2584, 3.1479, 3.1479, 3.9700, 2.9919, 2.9919, 2.9922, 2.9922, 2.9443, 2.9443, 2.9010, 2.839, 2.7982, 2.7982, 2.7374, 2.7374, 2.6716, 2.6716, 2.7378, 2.7378, 2.7378, 2.6416, 2.6416, 2.6416, 2.5768, 2.5768, 2.6374, 2.6374, 2.5618, 2.5618, 2.5618, 2.5348, 2.5283, 2.5009, 2.5009, 2.5009, 2.4616, 2.4616, 2.5369, 2.1287, 2.0695, 2.5369, 2.4410, 2.4651, 2.0695, 2.9756, 2.9756, 2.9756, 2.0695],
    [2.0019, 0.2905, 0.1600, 0.1540, 0.1540, 0.2471, 0.2471, 0.3045, 0.3045, 0.1925, 0.1925, 0.3281, 0.3281, 0.1670, 0.1670, 0.2189, 0.1167, 0.1167, 0.1560, 0.3281, 0.1670, 0.1670, 0.1925, 0.1925, 0.1600, 0.1600, 0.1670, 0.1670, 0.1670, 0.1670, 0.1670, 0.1670, 0.2905, 0.2905, 0.3045, 0.3045, 0.3045, 0.3045, 2.0019, 2.0019, 0.1600, 0.1600, 0.3045, 0.3045, 0.1925, 3.0168, 0.1167, 0.1167, 0.1560, 0.1560]
]

# Create a figure for the loss curves
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss curves for each model
styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-', 'k-', 'purple-']
for i in range(len(model_names)):
    ax.plot(range(1, 31), loss_data[i], styles[i], label=model_names[i], linewidth=2)

# Set labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('Loss Curves for 8 Models')
ax.legend(loc='upper right')
ax.grid(True)

# Add a background grid
ax.grid(linestyle='--', alpha=0.7)

# Adjust the axis ticks
ax.set_xticks(range(1, 31, 2))

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1cc1b471ab9c> in <cell line: 21>()
#      20 styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-', 'k-', 'purple-']
#      21 for i in range(len(model_names)):
# ---> 22     ax.plot(range(1, 31), loss_data[i], styles[i], label=model_names[i], linewidth=2)
#      23
#      24 # Set labels and title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have loss data for each model stored in lists
model_names = ["ConvNeXtBase", "ConvNeXtLarge", "EfficientNetV2L", "InceptionResNetV2", "ResNet152", "NasNet", "Proposed", "NewModel"]

loss_data = [
    [4.8470, 4.4064, 4.1217, 4.0502, 3.9700, 4.0140, 3.8759, 3.8759, 3.8442, 3.7500, 3.7500, 3.7500, 3.7500, 3.6936, 3.6936, 3.6936, 3.6879, 3.6879, 3.5913, 3.5432, 3.5723, 3.5510, 3.4728, 3.4728, 3.4538, 3.4771, 3.3610, 3.3610, 3.3638, 3.3638, 3.3647, 3.3728, 3.2406, 3.3128, 3.2895, 3.2623, 3.2623, 3.2516, 3.2338, 3.1326, 3.1280, 3.1584, 3.0951, 3.0597, 3.0512, 3.0168, 2.9756, 2.9756, 2.9756, 2.9756],
    [3.0691, 2.8622, 2.8907, 2.4208, 2.2881, 2.1980, 2.2679, 2.1545, 2.0941, 2.1070, 2.0632, 2.0948, 2.0414, 2.1612, 2.1612, 2.0986, 2.0830, 2.0830, 1.9955, 2.0054, 1.9997, 2.0149, 1.9840, 1.9863, 1.9542, 1.9299, 1.9391, 1.9217, 1.9456, 1.9373, 1.9045, 1.8914, 1.8790, 1.8784, 1.8845, 1.8818, 1.8687, 1.8809, 1.8207, 1.8459, 1.8686, 3.1584, 1.8547, 1.9015, 1.8168, 1.7740, 1.7551, 1.7474, 1.7263, 1.7384],
    [2.5131, 2.4412, 2.3641, 2.3033, 2.2461, 2.1707, 2.1231, 2.0446, 1.9991, 1.9991, 1.9330, 1.9365, 1.9248, 1.9248, 1.9012, 1.8548, 1.8451, 1.8451, 1.8351, 1.9013, 1.9013, 1.8105, 1.8217, 1.8066, 1.7914, 1.7667, 1.7658, 1.7658, 1.7429, 1.7183, 1.6757, 1.7278, 1.6947, 1.6880, 1.6762, 1.6547, 1.6508, 1.6539, 1.6905, 1.7251, 1.7222, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479, 1.7479],
    [2.7368, 2.7368, 2.6488, 2.5805, 2.5805, 2.5110, 2.4589, 2.4589, 2.4589, 2.4521, 2.4217, 2.4047, 2.3453, 2.2832, 2.3236, 2.2653, 2.3049, 2.2353, 2.2469, 2.2762, 2.2209, 2.1777, 2.2054, 2.1424, 2.1571, 2.1079, 2.1079, 2.1399, 2.1060, 2.0905, 2.0444, 2.0835, 2.0452, 2.1216, 2.0856, 2.0887, 3.2623, 2.0212, 1.9830, 1.9954, 2.0030, 2.0540, 2.0403, 1.9663, 1.9824, 1.9684, 2.0403, 2.0403, 2.0039, 2.0039],
    [3.1341, 3.1341, 2.7940, 2.7940, 2.7428, 2.7428, 2.6796, 2.6796, 2.6798, 2.6798, 2.6130, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5071, 2.5071, 2.4845, 2.4402, 2.5203, 2.4402, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.5335, 2.5335, 2.6170, 2.6170, 2.5485, 2.9756, 2.9756, 2.9756],
    [3.2584, 3.2584, 3.1479, 3.1479, 3.9700, 2.9919, 2.9919, 2.9922, 2.9922, 2.9443, 2.9443, 2.9010, 2.839, 2.7982, 2.7982, 2.7374, 2.7374, 2.6716, 2.6716, 2.7378, 2.7378, 2.7378, 2.6416, 2.6416, 2.6416, 2.5768, 2.5768, 2.6374, 2.6374, 2.5618, 2.5618, 2.5618, 2.5348, 2.5283, 2.5009, 2.5009, 2.5009, 2.4616, 2.4616, 2.5369, 2.1287, 2.0695, 2.5369, 2.4410, 2.4651, 2.0695, 2.9756, 2.9756, 2.9756, 2.0695],
    [2.0019, 0.2905, 0.1600, 0.1540, 0.1540, 0.2471, 0.2471, 0.3045, 0.3045, 0.1925, 0.1925, 0.3281, 0.3281, 0.1670, 0.1670, 0.2189, 0.1167, 0.1167, 0.1560, 0.3281, 0.1670, 0.1670, 0.1925, 0.1925, 0.1600, 0.1600, 0.1670, 0.1670, 0.1670, 0.1670, 0.1670, 0.1670, 0.2905, 0.2905, 0.3045, 0.3045, 0.3045, 0.3045, 2.0019, 2.0019, 0.1600, 0.1600, 0.3045, 0.3045, 0.1925, 3.0168, 0.1167, 0.1167, 0.1560, 0.1560]
]

# Create a figure for the loss curves
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss curves for each model
styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-', 'k-', 'purple-']
for i in range(len(model_names)):
    epochs = range(1, len(loss_data[i]) + 1)  # Update this line to match the number of epochs for each model
    ax.plot(epochs, loss_data[i], styles[i], label=model_names[i], linewidth=2)

# Set labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('Loss Curves for 8 Models')
ax.legend(loc='upper right')
ax.grid(True)

# Add a background grid
ax.grid(linestyle='--', alpha=0.7)

# Adjust the axis ticks
ax.set_xticks(range(1, len(loss_data[0]) + 1, 2))

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7f955bcc496f> in <cell line: 21>()
#      20 styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-', 'k-', 'purple-']
#      21 for i in range(len(model_names)):
# ---> 22     epochs = range(1, len(loss_data[i]) + 1)  # Update this line to match the number of epochs for each model
#      23     ax.plot(epochs, loss_data[i], styles[i], label=model_names[i], linewidth=2)
#      24
#
# IndexError: list index out of range

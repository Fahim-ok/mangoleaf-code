# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise')
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise')

# Set labels, title, and legend
ax.set_ylabel('Metric Values')
ax.set_title('WaveVisionNet Model Comparison')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the values on top of the bars
for bar in [bar1, bar2]:
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 4)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise')
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise')

# Set labels, title, and legend
ax.set_ylabel('Metric Values')
ax.set_title('WaveVisionNet Model Comparison')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the values on top of the bars
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 4)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height, 4)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Convert values to percentages
total_metrics = len(metrics)
without_noise_percentages = [value * 100 for value in without_noise_values]
with_noise_percentages = [value * 100 for value in with_noise_values]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_percentages, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_percentages, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars in percentage format
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{:.2f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Convert values to percentages
total_metrics = len(metrics)
without_noise_percentages = [value * 100 for value in without_noise_values]
with_noise_percentages = [value * 100 for value in with_noise_values]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_percentages, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_percentages, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars in percentage format
for i, (bar, values) in enumerate(zip([bar1, bar2], [without_noise_percentages, with_noise_percentages])):
    for j, rect in enumerate(bar):
        height = rect.get_height()
        offset = 10 if j % 2 == 0 else -15
        ax.annotate('{:.2f}%'.format(values[j]),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, offset),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] * 100 for metric in metrics]
with_noise_values = [with_noise[metric] * 100 for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.2)
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.2)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] * 100 for metric in metrics]
with_noise_values = [with_noise[metric] * 100 for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend with smaller font size
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=10)  # Smaller font size for legend

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# # Add smaller labels for "Without Noise" and "With Noise"
# ax.text(-0.2, 100, 'Without Noise', fontsize=10, color='#1f77b4')
# ax.text(len(metrics) - 0.1, 100, 'With Noise', fontsize=10, color='#ff7f0e')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Convert values to percentages
total_metrics = len(metrics)
without_noise_percentages = [value * 100 for value in without_noise_values]
with_noise_percentages = [value * 100 for value in with_noise_values]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars in percentage format
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{:.2f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Convert values to percentages
total_metrics = len(metrics)
without_noise_percentages = [value * 100 for value in without_noise_values]
with_noise_percentages = [value * 100 for value in with_noise_values]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_percentages, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_percentages, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars in percentage format
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{:.2f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    'loss': 0.0508,
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
    'loss': 0.0929,
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] for metric in metrics]
with_noise_values = [with_noise[metric] for metric in metrics]

# Convert values to percentages
total_metrics = len(metrics)
without_noise_percentages = [value * 100 for value in without_noise_values]
with_noise_percentages = [value * 100 for value in with_noise_values]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(12, 8))
bar1 = ax.bar(x - width/2, without_noise_percentages, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_percentages, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=12)

# Display the values on top of the bars in percentage format
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{:.2f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Add smaller labels for "Without Noise" and "With Noise"
ax.text(-0.2, 100, 'Without Noise', fontsize=8, color='#1f77b4')  # Adjust fontsize here
ax.text(len(metrics) - 0.1, 100, 'With Noise', fontsize=8, color='#ff7f0e')  # Adjust fontsize here

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the WaveVisionNet without noise
without_noise = {
    
    'accuracy': 0.9691,
    'auc': 0.9996,
    'precision': 0.9691,
    'recall': 0.9685,
    'cohen_kappa': 0.9678,
    'f1_score': 0.9647
}

# Data for the WaveVisionNet with noise
with_noise = {
   
    'accuracy': 0.9567,
    'auc': 0.9989,
    'precision': 0.9589,
    'recall': 0.9555,
    'cohen_kappa': 0.9548,
    'f1_score': 0.9511
}

# List of metrics
metrics = list(without_noise.keys())

# Data for plotting
without_noise_values = [without_noise[metric] * 100 for metric in metrics]
with_noise_values = [with_noise[metric] * 100 for metric in metrics]

# Set up positions for bars on X-axis
x = np.arange(len(metrics))

# Bar width
width = 0.35

# Create a stylish bar chart
fig, ax = plt.subplots(figsize=(18, 10))
bar1 = ax.bar(x - width/2, without_noise_values, width, label='Without Noise', color='#1f77b4', edgecolor='black', linewidth=1.5)
bar2 = ax.bar(x + width/2, with_noise_values, width, label='With Noise', color='#ff7f0e', edgecolor='black', linewidth=1.5)

# Set labels, title, and legend with smaller font size
ax.set_ylabel('Metric Values (%)', fontsize=14)
ax.set_title('WaveVisionNet Model Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=12)
ax.legend(fontsize=10)  # Smaller font size for legend


# Display the values on top of the bars in percentage format
for i, bar in enumerate([bar1, bar2]):
    for rect in bar:
        height = rect.get_height()
        ax.annotate('{:.2f}%'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3) if i == 0 else (0, -15),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')


# Add gridlines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# # Add smaller labels for "Without Noise" and "With Noise"
# ax.text(-0.2, 100, 'Without Noise', fontsize=10, color='#1f77b4')
# ax.text(len(metrics) - 0.1, 100, 'With Noise', fontsize=10, color='#ff7f0e')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
classes = ["Harivanga", "Gopal Vag", "Lengra", "Red palmar", "Madhurani", "Fazlee", "Moriyum",
           "Indian Totapori", "Kachamitha", "Philippines Honey Deu", "Taiwani Red", "Thai Moriyom",
           "Qzai", "Sabira", "Himsagar", "King Brunia", "African Jambo", "Amrapali", "Bari 4",
           "Bari 7", "Bari 8", "Bari 9", "Bari 11", "Bari 13", "Thai Banana Mango", "Baper Bari"]

num_images = [566, 402, 61, 69, 225, 415, 455, 675, 931, 899, 764, 738, 839, 738, 575, 591, 433, 981,
              447, 470, 659, 178, 293, 85, 212, 1288]

# Plotting the pie chart
plt.figure(figsize=(10, 10))
plt.pie(num_images, labels=classes, autopct='%1.1f%%', startangle=140)
plt.title('Data Distribution of Classes')
plt.show()

# %%
import plotly.express as px

# Data from the table
classes = ["Harivanga", "Gopal Vag", "Lengra", "Red palmar", "Madhurani", "Fazlee", "Moriyum",
           "Indian Totapori", "Kachamitha", "Philippines Honey Deu", "Taiwani Red", "Thai Moriyom",
           "Qzai", "Sabira", "Himsagar", "King Brunia", "African Jambo", "Amrapali", "Bari 4",
           "Bari 7", "Bari 8", "Bari 9", "Bari 11", "Bari 13", "Thai Banana Mango", "Baper Bari"]

num_images = [566, 402, 61, 69, 225, 415, 455, 675, 931, 899, 764, 738, 839, 738, 575, 591, 433, 981,
              447, 470, 659, 178, 293, 85, 212, 1288]

# Creating a pie chart using plotly
fig = px.pie(labels=classes, values=num_images, title='')
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the table
classes = ["Harivanga", "Gopal Vag", "Lengra", "Red palmar", "Madhurani", "Fazlee", "Moriyum",
           "Indian Totapori", "Kachamitha", "Philippines Honey Deu", "Taiwani Red", "Thai Moriyom",
           "Qzai", "Sabira", "Himsagar", "King Brunia", "African Jambo", "Amrapali", "Bari 4",
           "Bari 7", "Bari 8", "Bari 9", "Bari 11", "Bari 13", "Thai Banana Mango", "Baper Bari"]

num_images = [566, 402, 61, 69, 225, 415, 455, 675, 931, 899, 764, 738, 839, 738, 575, 591, 433, 981,
              447, 470, 659, 178, 293, 85, 212, 1288]

# Creating a pie chart using seaborn and matplotlib
plt.figure(figsize=(10, 10))
sns.set(style="whitegrid")
plt.pie(num_images, labels=classes, autopct='%1.1f%%', startangle=140)
plt.title('Data Distribution of Classes')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have the data in a Pandas DataFrame
data = {
    'Model': ['ConvNeXtLarge', 'ConvNeXtBase', 'InceptionResnetV2', 'VGG16', 'Improved SwinV2', 'Coatnet', 'MaxViT', 'WaveVisionNet'] * 3,
    'Input Dimension': [112, 128, 224] * 8,
    'Accuracy (%)': [82.27, 83.45, 81.34, 81.53, 82.41, 82.41, 81.53, 82.41, 83.14, 83.04, 83.04, 85.27, 83.14, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04, 85.27, 83.04, 83.04, 83.04],
    'Precision': [0.8811, 0.8722, 0.8701, 0.8153, 0.8153, 0.8242, 0.8242, 0.8042, 0.9693, 0.9491, 0.9551, 0.9070, 0.9183, 0.9270, 0.9614, 0.9411, 0.9314, 0.9572, 0.9584, 0.9373, 0.9781, 0.9780, 0.9680, 0.9724, 0.9814, 0.9723],
    'Recall': [0.7560, 0.7451, 0.7350, 0.7408, 0.7627, 0.7515, 0.9615, 0.9312, 0.1793, 0.1893, 0.1982, 0.7814, 0.7933, 0.7833, 0.9656, 0.9512, 0.9242, 0.9313, 0.9472, 0.9144, 0.9724, 0.9814, 0.9723, 0.9656, 0.9806, 0.9701],
    'F-1': [0.8134, 0.8128, 0.8012, 0.8137, 0.8257, 0.8243, 0.9126, 0.9514, 0.6155, 0.6020, 0.6244, 0.8330, 0.8250, 0.8240, 0.9460, 0.9660, 0.9343, 0.9434, 0.9416, 0.9215, 0.9501, 0.9806, 0.9701, 0.9460, 0.9806, 0.9701],
    'AUC': [0.9947, 0.9852, 0.9811, 0.9952, 0.9832, 0.9910, 0.9725, 0.9526, 0.9654, 0.9600, 0.9510, 0.9902, 0.9801, 0.9812, 0.9841, 0.9960, 0.9166, 0.9856, 0.9559, 0.9568, 0.9776, 0.9601, 0.9816, 0.9776, 0.9601, 0.9816],
    "Cohen's Kappa": [0.8153, 0.8242, 0.8021, 0.8131, 0.8120, 0.8230, 0.9402, 0.9611, 0.6212, 0.6492, 0.6292, 0.8464, 0.8153, 0.8384, 0.9656, 0.9503, 0.9423, 0.9555, 0.9154, 0.9254, 0.9661, 0.9874, 0.9754, 0.9661, 0.9874, 0.9754],
}

df = pd.DataFrame(data)

# Separate the data by model
models = df['Model'].unique()

# Create a separate plot for each metric
metrics = ['Accuracy (%)', 'Precision', 'Recall', 'F-1', 'AUC', "Cohen's Kappa"]

for metric in metrics:
    plt.figure(figsize=(12, 6))
    for model in models:
        model_data = df[df['Model'] == model]
        plt.plot(model_data['Input Dimension'], model_data[metric], marker='o', label=model)

    plt.title(f'{metric} vs. Input Dimension')
    plt.xlabel('Input Dimension')
    plt.ylabel(metric)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 16
#       4 # Assuming you have the data in a Pandas DataFrame
#       5 data = {
#       6     'Model': ['ConvNeXtLarge', 'ConvNeXtBase', 'InceptionResnetV2', 'VGG16', 'Improved SwinV2', 'Coatnet', 'MaxViT', 'WaveVisionNet'] * 3,
#       7     'Input Dimension': [112, 128, 224] * 8,
#    (...)
#      13     "Cohen's Kappa": [0.8153, 0.8242, 0.8021, 0.8131, 0.8120, 0.8230, 0.9402, 0.9611, 0.6212, 0.6492, 0.6292, 0.8464, 0.8153, 0.8384, 0.9656, 0.9503, 0.9423, 0.9555, 0.9154, 0.9254, 0.9661, 0.9874, 0.9754, 0.9661, 0.9874, 0.9754],
#      14 }
# ---> 16 df = pd.DataFrame(data)
#      18 # Separate the data by model
#      19 models = df['Model'].unique()
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
# ...

# %%
#medicinal

import matplotlib.pyplot as plt

# Data for one input dimension (112)
models = ["ConvNeXtLarge", "ConvNeXtBase", "InceptionResnetV2", "VGG16", "Improved SwinV2", "Coatnet", "MaxViT", "WaveVisionNet"]
accuracy = [0.8227, 0.8153, 0.6727, 0.8527, 0.9478, 0.9414, 0.9413, 0.9890]
precision = [0.8811, 0.8153, 0.9693, 0.9070, 0.9614, 0.9305, 0.9572, 0.9781]
recall = [0.7560, 0.7408, 0.1793, 0.7814, 0.9656, 0.9615, 0.9313, 0.9724]
f1 = [0.8134, 0.8137, 0.6155, 0.8330, 0.9460, 0.9126, 0.9434, 0.9501]
auc = [0.9947, 0.9952, 0.9654, 0.9902, 0.9841, 0.9725, 0.9856, 0.9776]
kappa = [0.8153, 0.8131, 0.6212, 0.8464, 0.9656, 0.9402, 0.9555, 0.9661]

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each metric for all models
for metric, values in zip(["Accuracy", "Precision", "Recall", "F1", "AUC", "Cohen's Kappa"], [accuracy, precision, recall, f1, auc, kappa]):
    ax.plot(models, values, label=metric, marker='o')

# Customize the plot
ax.set_title('Model Performance Comparison (Indian Medicinal Leaves Dataset)')
ax.set_xlabel('Models')
ax.set_ylabel('Metric Value')
ax.legend()
ax.grid(True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.tight_layout()
plt.show()

# %%
#mangofolio

import matplotlib.pyplot as plt

# Data for one input dimension (112)
models = ["ConvNeXtLarge", "ConvNeXtBase", "InceptionResnetV2", "VGG16", "Improved SwinV2", "Coatnet", "MaxViT", "WaveVisionNet"]
accuracy = [0.6163, 0.3227, 0.2704, 0.6125, 0.1297, 0.9525, 0.9572, 0.9723]
precision = [0.8686, 0.9195, 0.4000, 0.9032, 0.2397, 0.9405, 0.9484, 0.9710]
recall = [0.4073, 0.0407, 0.0060, 0.3450, 0.1297, 0.9715, 0.9472, 0.9615]
f1 = [0.5825, 0.2551, 0.2902, 0.5734, 0.2162, 0.956, 0.9527, 0.9544]
auc = [0.9504, 0.8506, 0.6028, 0.9504, 0.1484, 0.9786, 0.9989, 0.9831]
kappa = [0.5989, 0.2903, 0.1497, 0.5858, 0.1383, 0.9503, 0.9454, 0.9612]

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each metric for all models
for metric, values in zip(["Accuracy", "Precision", "Recall", "F1", "AUC", "Cohen's Kappa"], [accuracy, precision, recall, f1, auc, kappa]):
    ax.plot(models, values, label=metric, marker='o')

# Customize the plot
ax.set_title('Model Performance Comparison (MangoFolioBD Dataset')
ax.set_xlabel('Models')
ax.set_ylabel('Metric Value')
ax.legend()
ax.grid(True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tensorflow import keras
import seaborn as sns
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Flatten, Reshape, Conv2DTranspose, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.utils import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

np.random.seed(72)
tf.random.set_seed(72)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    
    # ROC curve
    plt.subplot(1, 2, 2)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(len(class_labels)):
        fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(len(class_labels)):
        plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

# Call the function with your model and test generator

# %%
train_dir = r"/kaggle/input/leaf-dataset/augmented/train"
test_dir = r"/kaggle/input/leaf-dataset/augmented/test"
datagen_train = ImageDataGenerator(rescale=1./255,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  horizontal_flip=True,
                                  vertical_flip=False)


datagen_test = ImageDataGenerator(rescale=1./255)


batch_size = 16
generator_train = datagen_train.flow_from_directory(directory=train_dir,
                                                    target_size=(112, 112),
                                                    batch_size=batch_size,
                                                    shuffle=True)

generator_test = datagen_test.flow_from_directory(directory=test_dir,
                                                  target_size=(112, 112),
                                                  batch_size=batch_size,
                                                  shuffle=False)
# Calculate class weights
labels = generator_train.classes
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)
class_weights = dict(zip(np.unique(labels), class_weights))
print(class_weights)
# Out:
# Found 5000 images belonging to 30 classes.
# Found 2500 images belonging to 30 classes.
# {0: 1.2820512820512822, 1: 0.4975124378109453, 2: 1.0101010101010102, 3: 1.016260162601626, 4: 0.5827505827505828, 5: 1.8726591760299625, 6: 0.778816199376947, 7: 1.2345679012345678, 8: 1.1111111111111112, 9: 0.9057971014492754, 10: 1.3440860215053763, 11: 0.8680555555555556, 12: 0.9009009009009009, 13: 0.6587615283267457, 14: 0.778816199376947, 15: 1.3123359580052494, 16: 0.9416195856873822, 17: 1.02880658436214, 18: 1.4880952380952381, 19: 1.1037527593818985, 20: 1.4492753623188406, 21: 1.3888888888888888, 22: 1.0040160642570282, 23: 1.0964912280701755, 24: 0.8169934640522876, 25: 0.8960573476702509, 26: 1.529051987767584, 27: 1.0964912280701755, 28: 1.1574074074074074, 29: 1.6181229773462784}

# %%
# !pip install keras_cv_attention_models
# Out:
# Collecting keras_cv_attention_models
#   Obtaining dependency information for keras_cv_attention_models from https://files.pythonhosted.org/packages/f0/02/d10f684e57fc993cc90c9c7610df4e77239f8d1c395f67c3e687109eae6b/keras_cv_attention_models-1.3.23-py3-none-any.whl.metadata
#   Downloading keras_cv_attention_models-1.3.23-py3-none-any.whl.metadata (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (10.1.0)
# Collecting ftfy (from keras_cv_attention_models)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (2023.8.8)
# Requirement already satisfied: tensorflow-datasets in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (4.9.2)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (2.13.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->keras_cv_attention_models)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (68.1.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.34.0)
# Requirement already satisfied: array-record in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.4.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (8.1.7)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.1.8)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (1.4.1)
# Requirement already satisfied: promise in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (2.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (5.9.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (2.31.0)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.14.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.10.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (4.66.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->keras_cv_attention_models) (0.41.2)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras_cv_attention_models) (5.13.0)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras_cv_attention_models) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (2023.11.17)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow->keras_cv_attention_models) (3.0.9)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.10/site-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv_attention_models) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras_cv_attention_models) (3.2.2)
# Downloading keras_cv_attention_models-1.3.23-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.9/786.9 kB 10.1 MB/s eta 0:00:0000:010:01
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 4.9 MB/s eta 0:00:00
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, ftfy, keras_cv_attention_models
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
# Successfully installed ftfy-6.1.3 keras_cv_attention_models-1.3.23 wcwidth-0.2.12

# %%
from keras_cv_attention_models import wave_mlp

# %%
pip install keras-self-attention
# Out:
# Requirement already satisfied: keras-self-attention in /opt/conda/lib/python3.10/site-packages (0.51.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras-self-attention) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
def modify_wave_mlp(input_shape, num_classes):
    # Load the WaveMLP model without the top layers (head)
    mm_headless = wave_mlp.WaveMLP_T(input_shape=input_shape, pretrained="imagenet")

    # Initialize x with the output of the base model
    x = mm_headless.output

#     # Stage 2 with HDC
#     x = stage_block(x, filters=128, num_blocks=3, hdc=True)

#     # Stage 3 with HDC
#     x = stage_block(x, filters=256, num_blocks=3, hdc=True)

    # Stage 4 (Residual blocks)
    x = stage_block(x, filters=512, num_blocks=3, attention=False, hdc=False)

    # Custom head
    head_output = custom_head(x, num_classes)

    # Create the custom model by combining the base model and the custom head
    custom_model = Model(inputs=mm_headless.input, outputs=head_output)

    return custom_model

# %%
input_shape = (112, 112, 3)
num_classes = 26

# Assign the result of modify_wave_mlp to a variable
custom_model = modify_wave_mlp(input_shape, num_classes)

# Now you can use custom_model outside of the function
mm_last_layer = custom_model.get_layer('avg_pool').output
mm_custom = Model(custom_model.input, mm_last_layer)
# Out:
# >>>> Load pretrained from: /root/.keras/models/wavemlp_t_imagenet.h5

# %%
custom_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 112, 112, 3)]        0         []
#
#  stem_pad (ZeroPadding2D)    (None, 116, 116, 3)          0         ['input_4[0][0]']
#
#  stem_conv (Conv2D)          (None, 28, 28, 64)           9472      ['stem_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 28, 28, 64)           256       ['stem_conv[0][0]']
#  n)
#
#  stack1_block1_attn_bn (Bat  (None, 28, 28, 64)           256       ['stem_bn[0][0]']
#  chNormalization)
#
#  stack1_block1_attn_theta_h  (None, 28, 28, 64)           4160      ['stack1_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block1_attn_theta_w  (None, 28, 28, 64)           4160      ['stack1_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block1_attn_theta_h  (None, 28, 28, 64)           256       ['stack1_block1_attn_theta_h_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack1_block1_attn_theta_w  (None, 28, 28, 64)           256       ['stack1_block1_attn_theta_w_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack1_block1_attn_theta_h  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_h_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack1_block1_attn_theta_w  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_w_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack1_block1_attn_height_  (None, 28, 28, 64)           4096      ['stack1_block1_attn_bn[0][0]'
#  conv (Conv2D)                                                      ]
#
#  tf.math.cos_40 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_40 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  stack1_block1_attn_width_c  (None, 28, 28, 64)           4096      ['stack1_block1_attn_bn[0][0]'
#  onv (Conv2D)                                                       ]
#
#  tf.math.cos_41 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_41 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block1_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  multiply_140 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.cos_40[0][0]']
#
#  multiply_141 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.sin_40[0][0]']
#
#  multiply_142 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.cos_41[0][0]']
#
#  multiply_143 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.sin_41[0][0]']
#
#  concatenate_40 (Concatenat  (None, 28, 28, 128)          0         ['multiply_140[0][0]',
#  e)                                                                  'multiply_141[0][0]']
#
#  concatenate_41 (Concatenat  (None, 28, 28, 128)          0         ['multiply_142[0][0]',
#  e)                                                                  'multiply_143[0][0]']
#
#  stack1_block1_attn_height_  (None, 28, 34, 128)          0         ['concatenate_40[0][0]']
#  down_pad (ZeroPadding2D)
#
#  stack1_block1_attn_width_d  (None, 34, 28, 128)          0         ['concatenate_41[0][0]']
#  own_pad (ZeroPadding2D)
#
#  stack1_block1_attn_height_  (None, 28, 28, 64)           896       ['stack1_block1_attn_height_do
#  down_conv (Conv2D)                                                 wn_pad[0][0]']
#
#  stack1_block1_attn_width_d  (None, 28, 28, 64)           896       ['stack1_block1_attn_width_dow
#  own_conv (Conv2D)                                                  n_pad[0][0]']
#
#  stack1_block1_attn_channel  (None, 28, 28, 64)           4096      ['stack1_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block1_attn_combine  (None, 28, 28, 64)           0         ['stack1_block1_attn_height_do
#   (Add)                                                             wn_conv[0][0]',
#                                                                      'stack1_block1_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'stack1_block1_attn_channel_c
#                                                                     onv[0][0]']
#
#  global_average_pooling2d_2  (None, 1, 1, 64)             0         ['stack1_block1_attn_combine[0
#  0 (GlobalAveragePooling2D)                                         ][0]']
#
#  stack1_block1_attn_reweigh  (None, 1, 1, 16)             1040      ['global_average_pooling2d_20[
#  t_Conv_0 (Conv2D)                                                  0][0]']
#
#  stack1_block1_attn_reweigh  (None, 1, 1, 16)             0         ['stack1_block1_attn_reweight_
#  t_gelugelu (Activation)                                            Conv_0[0][0]']
#
#  stack1_block1_attn_reweigh  (None, 1, 1, 192)            3264      ['stack1_block1_attn_reweight_
#  t_Conv_1 (Conv2D)                                                  gelugelu[0][0]']
#
#  reshape_20 (Reshape)        (None, 1, 1, 64, 3)          0         ['stack1_block1_attn_reweight_
#                                                                     Conv_1[0][0]']
#
#  stack1_block1_attn_attenti  (None, 1, 1, 64, 3)          0         ['reshape_20[0][0]']
#  on_scores (Softmax)
#
#  tf.unstack_20 (TFOpLambda)  [(None, 1, 1, 64),           0         ['stack1_block1_attn_attention
#                               (None, 1, 1, 64),                     _scores[0][0]']
#                               (None, 1, 1, 64)]
#
#  multiply_144 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_height_do
#                                                                     wn_conv[0][0]',
#                                                                      'tf.unstack_20[0][0]']
#
#  multiply_145 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'tf.unstack_20[0][1]']
#
#  multiply_146 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block1_attn_channel_c
#                                                                     onv[0][0]',
#                                                                      'tf.unstack_20[0][2]']
#
#  add_31 (Add)                (None, 28, 28, 64)           0         ['multiply_144[0][0]',
#                                                                      'multiply_145[0][0]',
#                                                                      'multiply_146[0][0]']
#
#  stack1_block1_attn_out_con  (None, 28, 28, 64)           4160      ['add_31[0][0]']
#  v (Conv2D)
#
#  stack1_block1_attn_out (Ad  (None, 28, 28, 64)           0         ['stem_bn[0][0]',
#  d)                                                                  'stack1_block1_attn_out_conv[
#                                                                     0][0]']
#
#  stack1_block1_mlp_bn (Batc  (None, 28, 28, 64)           256       ['stack1_block1_attn_out[0][0]
#  hNormalization)                                                    ']
#
#  stack1_block1_mlp_Conv_0 (  (None, 28, 28, 256)          16640     ['stack1_block1_mlp_bn[0][0]']
#  Conv2D)
#
#  stack1_block1_mlp_gelugelu  (None, 28, 28, 256)          0         ['stack1_block1_mlp_Conv_0[0][
#   (Activation)                                                      0]']
#
#  stack1_block1_mlp_Conv_1 (  (None, 28, 28, 64)           16448     ['stack1_block1_mlp_gelugelu[0
#  Conv2D)                                                            ][0]']
#
#  stack1_block1_mlp_out (Add  (None, 28, 28, 64)           0         ['stack1_block1_attn_out[0][0]
#  )                                                                  ',
#                                                                      'stack1_block1_mlp_Conv_1[0][
#                                                                     0]']
#
#  stack1_block2_attn_bn (Bat  (None, 28, 28, 64)           256       ['stack1_block1_mlp_out[0][0]'
#  chNormalization)                                                   ]
#
#  stack1_block2_attn_theta_h  (None, 28, 28, 64)           4160      ['stack1_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block2_attn_theta_w  (None, 28, 28, 64)           4160      ['stack1_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block2_attn_theta_h  (None, 28, 28, 64)           256       ['stack1_block2_attn_theta_h_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack1_block2_attn_theta_w  (None, 28, 28, 64)           256       ['stack1_block2_attn_theta_w_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack1_block2_attn_theta_h  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_h_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack1_block2_attn_theta_w  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_w_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack1_block2_attn_height_  (None, 28, 28, 64)           4096      ['stack1_block2_attn_bn[0][0]'
#  conv (Conv2D)                                                      ]
#
#  tf.math.cos_42 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_42 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  stack1_block2_attn_width_c  (None, 28, 28, 64)           4096      ['stack1_block2_attn_bn[0][0]'
#  onv (Conv2D)                                                       ]
#
#  tf.math.cos_43 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_43 (TFOpLambda  (None, 28, 28, 64)           0         ['stack1_block2_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  multiply_147 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.cos_42[0][0]']
#
#  multiply_148 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.sin_42[0][0]']
#
#  multiply_149 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.cos_43[0][0]']
#
#  multiply_150 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.sin_43[0][0]']
#
#  concatenate_42 (Concatenat  (None, 28, 28, 128)          0         ['multiply_147[0][0]',
#  e)                                                                  'multiply_148[0][0]']
#
#  concatenate_43 (Concatenat  (None, 28, 28, 128)          0         ['multiply_149[0][0]',
#  e)                                                                  'multiply_150[0][0]']
#
#  stack1_block2_attn_height_  (None, 28, 34, 128)          0         ['concatenate_42[0][0]']
#  down_pad (ZeroPadding2D)
#
#  stack1_block2_attn_width_d  (None, 34, 28, 128)          0         ['concatenate_43[0][0]']
#  own_pad (ZeroPadding2D)
#
#  stack1_block2_attn_height_  (None, 28, 28, 64)           896       ['stack1_block2_attn_height_do
#  down_conv (Conv2D)                                                 wn_pad[0][0]']
#
#  stack1_block2_attn_width_d  (None, 28, 28, 64)           896       ['stack1_block2_attn_width_dow
#  own_conv (Conv2D)                                                  n_pad[0][0]']
#
#  stack1_block2_attn_channel  (None, 28, 28, 64)           4096      ['stack1_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack1_block2_attn_combine  (None, 28, 28, 64)           0         ['stack1_block2_attn_height_do
#   (Add)                                                             wn_conv[0][0]',
#                                                                      'stack1_block2_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'stack1_block2_attn_channel_c
#                                                                     onv[0][0]']
#
#  global_average_pooling2d_2  (None, 1, 1, 64)             0         ['stack1_block2_attn_combine[0
#  1 (GlobalAveragePooling2D)                                         ][0]']
#
#  stack1_block2_attn_reweigh  (None, 1, 1, 16)             1040      ['global_average_pooling2d_21[
#  t_Conv_0 (Conv2D)                                                  0][0]']
#
#  stack1_block2_attn_reweigh  (None, 1, 1, 16)             0         ['stack1_block2_attn_reweight_
#  t_gelugelu (Activation)                                            Conv_0[0][0]']
#
#  stack1_block2_attn_reweigh  (None, 1, 1, 192)            3264      ['stack1_block2_attn_reweight_
#  t_Conv_1 (Conv2D)                                                  gelugelu[0][0]']
#
#  reshape_21 (Reshape)        (None, 1, 1, 64, 3)          0         ['stack1_block2_attn_reweight_
#                                                                     Conv_1[0][0]']
#
#  stack1_block2_attn_attenti  (None, 1, 1, 64, 3)          0         ['reshape_21[0][0]']
#  on_scores (Softmax)
#
#  tf.unstack_21 (TFOpLambda)  [(None, 1, 1, 64),           0         ['stack1_block2_attn_attention
#                               (None, 1, 1, 64),                     _scores[0][0]']
#                               (None, 1, 1, 64)]
#
#  multiply_151 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_height_do
#                                                                     wn_conv[0][0]',
#                                                                      'tf.unstack_21[0][0]']
#
#  multiply_152 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'tf.unstack_21[0][1]']
#
#  multiply_153 (Multiply)     (None, 28, 28, 64)           0         ['stack1_block2_attn_channel_c
#                                                                     onv[0][0]',
#                                                                      'tf.unstack_21[0][2]']
#
#  add_32 (Add)                (None, 28, 28, 64)           0         ['multiply_151[0][0]',
#                                                                      'multiply_152[0][0]',
#                                                                      'multiply_153[0][0]']
#
#  stack1_block2_attn_out_con  (None, 28, 28, 64)           4160      ['add_32[0][0]']
#  v (Conv2D)
#
#  stack1_block2_attn_out (Ad  (None, 28, 28, 64)           0         ['stack1_block1_mlp_out[0][0]'
#  d)                                                                 , 'stack1_block2_attn_out_conv
#                                                                     [0][0]']
#
#  stack1_block2_mlp_bn (Batc  (None, 28, 28, 64)           256       ['stack1_block2_attn_out[0][0]
#  hNormalization)                                                    ']
#
#  stack1_block2_mlp_Conv_0 (  (None, 28, 28, 256)          16640     ['stack1_block2_mlp_bn[0][0]']
#  Conv2D)
#
#  stack1_block2_mlp_gelugelu  (None, 28, 28, 256)          0         ['stack1_block2_mlp_Conv_0[0][
#   (Activation)                                                      0]']
#
#  stack1_block2_mlp_Conv_1 (  (None, 28, 28, 64)           16448     ['stack1_block2_mlp_gelugelu[0
#  Conv2D)                                                            ][0]']
#
#  stack1_block2_mlp_out (Add  (None, 28, 28, 64)           0         ['stack1_block2_attn_out[0][0]
#  )                                                                  ',
#                                                                      'stack1_block2_mlp_Conv_1[0][
#                                                                     0]']
#
#  stack2_down_sample_pad (Ze  (None, 30, 30, 64)           0         ['stack1_block2_mlp_out[0][0]'
#  roPadding2D)                                                       ]
#
#  stack2_down_sample_conv (C  (None, 14, 14, 128)          73856     ['stack2_down_sample_pad[0][0]
#  onv2D)                                                             ']
#
#  stack2_down_sample_bn (Bat  (None, 14, 14, 128)          512       ['stack2_down_sample_conv[0][0
#  chNormalization)                                                   ]']
#
#  stack2_block1_attn_bn (Bat  (None, 14, 14, 128)          512       ['stack2_down_sample_bn[0][0]'
#  chNormalization)                                                   ]
#
#  stack2_block1_attn_theta_h  (None, 14, 14, 128)          16512     ['stack2_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack2_block1_attn_theta_w  (None, 14, 14, 128)          16512     ['stack2_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack2_block1_attn_theta_h  (None, 14, 14, 128)          512       ['stack2_block1_attn_theta_h_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack2_block1_attn_theta_w  (None, 14, 14, 128)          512       ['stack2_block1_attn_theta_w_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack2_block1_attn_theta_h  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_h_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack2_block1_attn_theta_w  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_w_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack2_block1_attn_height_  (None, 14, 14, 128)          16384     ['stack2_block1_attn_bn[0][0]'
#  conv (Conv2D)                                                      ]
#
#  tf.math.cos_44 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_44 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  stack2_block1_attn_width_c  (None, 14, 14, 128)          16384     ['stack2_block1_attn_bn[0][0]'
#  onv (Conv2D)                                                       ]
#
#  tf.math.cos_45 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_45 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block1_attn_theta_w_r
#  )                                                                  elu[0][0]']
#
#  multiply_154 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.cos_44[0][0]']
#
#  multiply_155 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_height_co
#                                                                     nv[0][0]',
#                                                                      'tf.math.sin_44[0][0]']
#
#  multiply_156 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.cos_45[0][0]']
#
#  multiply_157 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_width_con
#                                                                     v[0][0]',
#                                                                      'tf.math.sin_45[0][0]']
#
#  concatenate_44 (Concatenat  (None, 14, 14, 256)          0         ['multiply_154[0][0]',
#  e)                                                                  'multiply_155[0][0]']
#
#  concatenate_45 (Concatenat  (None, 14, 14, 256)          0         ['multiply_156[0][0]',
#  e)                                                                  'multiply_157[0][0]']
#
#  stack2_block1_attn_height_  (None, 14, 20, 256)          0         ['concatenate_44[0][0]']
#  down_pad (ZeroPadding2D)
#
#  stack2_block1_attn_width_d  (None, 20, 14, 256)          0         ['concatenate_45[0][0]']
#  own_pad (ZeroPadding2D)
#
#  stack2_block1_attn_height_  (None, 14, 14, 128)          1792      ['stack2_block1_attn_height_do
#  down_conv (Conv2D)                                                 wn_pad[0][0]']
#
#  stack2_block1_attn_width_d  (None, 14, 14, 128)          1792      ['stack2_block1_attn_width_dow
#  own_conv (Conv2D)                                                  n_pad[0][0]']
#
#  stack2_block1_attn_channel  (None, 14, 14, 128)          16384     ['stack2_block1_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack2_block1_attn_combine  (None, 14, 14, 128)          0         ['stack2_block1_attn_height_do
#   (Add)                                                             wn_conv[0][0]',
#                                                                      'stack2_block1_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'stack2_block1_attn_channel_c
#                                                                     onv[0][0]']
#
#  global_average_pooling2d_2  (None, 1, 1, 128)            0         ['stack2_block1_attn_combine[0
#  2 (GlobalAveragePooling2D)                                         ][0]']
#
#  stack2_block1_attn_reweigh  (None, 1, 1, 32)             4128      ['global_average_pooling2d_22[
#  t_Conv_0 (Conv2D)                                                  0][0]']
#
#  stack2_block1_attn_reweigh  (None, 1, 1, 32)             0         ['stack2_block1_attn_reweight_
#  t_gelugelu (Activation)                                            Conv_0[0][0]']
#
#  stack2_block1_attn_reweigh  (None, 1, 1, 384)            12672     ['stack2_block1_attn_reweight_
#  t_Conv_1 (Conv2D)                                                  gelugelu[0][0]']
#
#  reshape_22 (Reshape)        (None, 1, 1, 128, 3)         0         ['stack2_block1_attn_reweight_
#                                                                     Conv_1[0][0]']
#
#  stack2_block1_attn_attenti  (None, 1, 1, 128, 3)         0         ['reshape_22[0][0]']
#  on_scores (Softmax)
#
#  tf.unstack_22 (TFOpLambda)  [(None, 1, 1, 128),          0         ['stack2_block1_attn_attention
#                               (None, 1, 1, 128),                    _scores[0][0]']
#                               (None, 1, 1, 128)]
#
#  multiply_158 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_height_do
#                                                                     wn_conv[0][0]',
#                                                                      'tf.unstack_22[0][0]']
#
#  multiply_159 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'tf.unstack_22[0][1]']
#
#  multiply_160 (Multiply)     (None, 14, 14, 128)          0         ['stack2_block1_attn_channel_c
#                                                                     onv[0][0]',
#                                                                      'tf.unstack_22[0][2]']
#
#  add_33 (Add)                (None, 14, 14, 128)          0         ['multiply_158[0][0]',
#                                                                      'multiply_159[0][0]',
#                                                                      'multiply_160[0][0]']
#
#  stack2_block1_attn_out_con  (None, 14, 14, 128)          16512     ['add_33[0][0]']
#  v (Conv2D)
#
#  stack2_block1_attn_out (Ad  (None, 14, 14, 128)          0         ['stack2_down_sample_bn[0][0]'
#  d)                                                                 , 'stack2_block1_attn_out_conv
#                                                                     [0][0]']
#
#  stack2_block1_mlp_bn (Batc  (None, 14, 14, 128)          512       ['stack2_block1_attn_out[0][0]
#  hNormalization)                                                    ']
#
#  stack2_block1_mlp_Conv_0 (  (None, 14, 14, 512)          66048     ['stack2_block1_mlp_bn[0][0]']
#  Conv2D)
#
#  stack2_block1_mlp_gelugelu  (None, 14, 14, 512)          0         ['stack2_block1_mlp_Conv_0[0][
#   (Activation)                                                      0]']
#
#  stack2_block1_mlp_Conv_1 (  (None, 14, 14, 128)          65664     ['stack2_block1_mlp_gelugelu[0
#  Conv2D)                                                            ][0]']
#
#  stack2_block1_mlp_out (Add  (None, 14, 14, 128)          0         ['stack2_block1_attn_out[0][0]
#  )                                                                  ',
#                                                                      'stack2_block1_mlp_Conv_1[0][
#                                                                     0]']
#
#  stack2_block2_attn_bn (Bat  (None, 14, 14, 128)          512       ['stack2_block1_mlp_out[0][0]'
#  chNormalization)                                                   ]
#
#  stack2_block2_attn_theta_h  (None, 14, 14, 128)          16512     ['stack2_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack2_block2_attn_theta_w  (None, 14, 14, 128)          16512     ['stack2_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack2_block2_attn_theta_h  (None, 14, 14, 128)          512       ['stack2_block2_attn_theta_h_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack2_block2_attn_theta_w  (None, 14, 14, 128)          512       ['stack2_block2_attn_theta_w_c
#  _bn (BatchNormalization)                                           onv[0][0]']
#
#  stack2_block2_attn_theta_h  (None, 14, 14, 128)          0         ['stack2_block2_attn_theta_h_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack2_block2_attn_theta_w  (None, 14, 14, 128)          0         ['stack2_block2_attn_theta_w_b
#  _relu (Activation)                                                 n[0][0]']
#
#  stack2_block2_attn_height_  (None, 14, 14, 128)          16384     ['stack2_block2_attn_bn[0][0]'
#  conv (Conv2D)                                                      ]
#
#  tf.math.cos_46 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block2_attn_theta_h_r
#  )                                                                  elu[0][0]']
#
#  tf.math.sin_46 (TFOpLambda  (None, 14, 14, 128)          0         ['stack2_block2_attn_theta_h_r
# ...
#  stack4_block2_attn_height_  (None, 4, 10, 1024)          0         ['concatenate_58[0][0]']
#  down_pad (ZeroPadding2D)
#
#  stack4_block2_attn_width_d  (None, 10, 4, 1024)          0         ['concatenate_59[0][0]']
#  own_pad (ZeroPadding2D)
#
#  stack4_block2_attn_height_  (None, 4, 4, 512)            7168      ['stack4_block2_attn_height_do
#  down_conv (Conv2D)                                                 wn_pad[0][0]']
#
#  stack4_block2_attn_width_d  (None, 4, 4, 512)            7168      ['stack4_block2_attn_width_dow
#  own_conv (Conv2D)                                                  n_pad[0][0]']
#
#  stack4_block2_attn_channel  (None, 4, 4, 512)            262144    ['stack4_block2_attn_bn[0][0]'
#  _conv (Conv2D)                                                     ]
#
#  stack4_block2_attn_combine  (None, 4, 4, 512)            0         ['stack4_block2_attn_height_do
#   (Add)                                                             wn_conv[0][0]',
#                                                                      'stack4_block2_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'stack4_block2_attn_channel_c
#                                                                     onv[0][0]']
#
#  global_average_pooling2d_2  (None, 1, 1, 512)            0         ['stack4_block2_attn_combine[0
#  9 (GlobalAveragePooling2D)                                         ][0]']
#
#  stack4_block2_attn_reweigh  (None, 1, 1, 128)            65664     ['global_average_pooling2d_29[
#  t_Conv_0 (Conv2D)                                                  0][0]']
#
#  stack4_block2_attn_reweigh  (None, 1, 1, 128)            0         ['stack4_block2_attn_reweight_
#  t_gelugelu (Activation)                                            Conv_0[0][0]']
#
#  stack4_block2_attn_reweigh  (None, 1, 1, 1536)           198144    ['stack4_block2_attn_reweight_
#  t_Conv_1 (Conv2D)                                                  gelugelu[0][0]']
#
#  reshape_29 (Reshape)        (None, 1, 1, 512, 3)         0         ['stack4_block2_attn_reweight_
#                                                                     Conv_1[0][0]']
#
#  stack4_block2_attn_attenti  (None, 1, 1, 512, 3)         0         ['reshape_29[0][0]']
#  on_scores (Softmax)
#
#  tf.unstack_29 (TFOpLambda)  [(None, 1, 1, 512),          0         ['stack4_block2_attn_attention
#                               (None, 1, 1, 512),                    _scores[0][0]']
#                               (None, 1, 1, 512)]
#
#  multiply_207 (Multiply)     (None, 4, 4, 512)            0         ['stack4_block2_attn_height_do
#                                                                     wn_conv[0][0]',
#                                                                      'tf.unstack_29[0][0]']
#
#  multiply_208 (Multiply)     (None, 4, 4, 512)            0         ['stack4_block2_attn_width_dow
#                                                                     n_conv[0][0]',
#                                                                      'tf.unstack_29[0][1]']
#
#  multiply_209 (Multiply)     (None, 4, 4, 512)            0         ['stack4_block2_attn_channel_c
#                                                                     onv[0][0]',
#                                                                      'tf.unstack_29[0][2]']
#
#  add_40 (Add)                (None, 4, 4, 512)            0         ['multiply_207[0][0]',
#                                                                      'multiply_208[0][0]',
#                                                                      'multiply_209[0][0]']
#
#  stack4_block2_attn_out_con  (None, 4, 4, 512)            262656    ['add_40[0][0]']
#  v (Conv2D)
#
#  stack4_block2_attn_out (Ad  (None, 4, 4, 512)            0         ['stack4_block1_mlp_out[0][0]'
#  d)                                                                 , 'stack4_block2_attn_out_conv
#                                                                     [0][0]']
#
#  stack4_block2_mlp_bn (Batc  (None, 4, 4, 512)            2048      ['stack4_block2_attn_out[0][0]
#  hNormalization)                                                    ']
#
#  stack4_block2_mlp_Conv_0 (  (None, 4, 4, 2048)           1050624   ['stack4_block2_mlp_bn[0][0]']
#  Conv2D)
#
#  stack4_block2_mlp_gelugelu  (None, 4, 4, 2048)           0         ['stack4_block2_mlp_Conv_0[0][
#   (Activation)                                                      0]']
#
#  stack4_block2_mlp_Conv_1 (  (None, 4, 4, 512)            1049088   ['stack4_block2_mlp_gelugelu[0
#  Conv2D)                                                            ][0]']
#
#  stack4_block2_mlp_out (Add  (None, 4, 4, 512)            0         ['stack4_block2_attn_out[0][0]
#  )                                                                  ',
#                                                                      'stack4_block2_mlp_Conv_1[0][
#                                                                     0]']
#
#  output_bn (BatchNormalizat  (None, 4, 4, 512)            2048      ['stack4_block2_mlp_out[0][0]'
#  ion)                                                               ]
#
#  avg_pool (GlobalAveragePoo  (None, 512)                  0         ['output_bn[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 513000    ['avg_pool[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 31, 31, 1)            0         ['predictions[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 31, 31, 512)          5120      ['tf.reshape_1[0][0]']
#
#  batch_normalization_15 (Ba  (None, 31, 31, 512)          2048      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 31, 31, 512)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 31, 31, 512)          1024      ['tf.reshape_1[0][0]']
#
#  add_41 (Add)                (None, 31, 31, 512)          0         ['activation_15[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 31, 31, 512)          2359808   ['add_41[0][0]']
#
#  batch_normalization_16 (Ba  (None, 31, 31, 512)          2048      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 31, 31, 512)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 31, 31, 512)          262656    ['add_41[0][0]']
#
#  add_42 (Add)                (None, 31, 31, 512)          0         ['activation_16[0][0]',
#                                                                      'conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 31, 31, 512)          2359808   ['add_42[0][0]']
#
#  batch_normalization_17 (Ba  (None, 31, 31, 512)          2048      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 31, 31, 512)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 31, 31, 512)          262656    ['add_42[0][0]']
#
#  add_43 (Add)                (None, 31, 31, 512)          0         ['activation_17[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 512)          0         ['add_43[0][0]']
#  g2D)
#
#  flatten_1 (Flatten)         (None, 115200)               0         ['max_pooling2d_3[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  2949145   ['flatten_1[0][0]']
#                                                           6
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_2[0][0]']
#
#  self_attention_7 (SelfAtte  (None, 256)                  196608    ['dropout_1[0][0]']
#  ntion)
#
#  add_44 (Add)                (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'self_attention_7[0][0]']
#
#  positional_encoding_1 (Pos  (1, 1, 256, 256)             256       ['add_44[0][0]']
#  itionalEncoding)
#
#  add_45 (Add)                (None, 1, 256, 256)          0         ['add_44[0][0]',
#                                                                      'positional_encoding_1[0][0]'
#                                                                     ]
#
#  dense_3 (Dense)             (None, 1, 256, 26)           6682      ['add_45[0][0]']
#
# ==================================================================================================
# Total params: 52169954 (199.01 MB)
# Trainable params: 52142306 (198.91 MB)
# Non-trainable params: 27648 (108.00 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import layers
inputs = keras.Input(shape=(112,112,3))
outputs = layers.average([mm_custom(inputs)])

avg_ensemble_model = keras.Model(inputs=inputs, outputs=outputs)
avg_ensemble_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  model_1 (Functional)        (None, 512)               16704736
#
#  average (Average)           (None, 512)               0
#
# =================================================================
# Total params: 16704736 (63.72 MB)
# Trainable params: 16680160 (63.63 MB)
# Non-trainable params: 24576 (96.00 KB)
# _________________________________________________________________

# %%
num_classes = 30
avg_ensemble_model_last_layer = avg_ensemble_model.get_layer('average').output
output_layer = Dense(num_classes, activation='softmax', name='output_1')(avg_ensemble_model_last_layer)
final_model = Model(avg_ensemble_model.input, output_layer)

final_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  model_1 (Functional)        (None, 512)               16704736
#
#  average (Average)           (None, 512)               0
#
#  output_1 (Dense)            (None, 30)                15390
#
# =================================================================
# Total params: 16720126 (63.78 MB)
# Trainable params: 16695550 (63.69 MB)
# Non-trainable params: 24576 (96.00 KB)
# _________________________________________________________________

# %%
optimizer = Adam(lr=1e-5)
loss = 'categorical_crossentropy'
# metrics = ['categorical_accuracy']
metrics = ['accuracy', 'categorical_accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 
           tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), 
           tf.keras.metrics.FalseNegatives(), tfa.metrics.CohenKappa(num_classes = num_classes), 
           tfa.metrics.F1Score(num_classes = num_classes)]

final_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1,
    patience=9, mode="max", min_delta=0.0001, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(filepath='Best_DenseNet201_v23.h5', save_best_only=True, monitor = 'val_accuracy', verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

callbacks = [lr, checkpoint, early_stopping]

# %%
epochs = 30

steps_per_epoch = generator_train.n / batch_size
steps_test = generator_test.n / batch_size

history = final_model.fit_generator(generator=generator_train,
                                  epochs=epochs,
                                  steps_per_epoch=steps_per_epoch,
                                  validation_data=generator_test,
                                  validation_steps=steps_test,
                                   callbacks=callbacks, class_weight =class_weights)
# Out:
# /tmp/ipykernel_42/2027776823.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = final_model.fit_generator(generator=generator_train,
# Epoch 1/30
# 313/312 [==============================] - ETA: 0s - loss: 0.3524 - accuracy: 0.8994 - categorical_accuracy: 0.8994 - auc_1: 0.9928 - precision_1: 0.9306 - recall_1: 0.8768 - true_positives_1: 4384.0000 - true_negatives_1: 144673.0000 - false_positives_1: 327.0000 - false_negatives_1: 616.0000 - cohen_kappa: 0.8956 - f1_score: 0.8972
# Epoch 1: val_accuracy improved from -inf to 0.89800, saving model to Best_DenseNet201_v23.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 312/312 [==============================] - 139s 296ms/step - loss: 0.3524 - accuracy: 0.8994 - categorical_accuracy: 0.8994 - auc_1: 0.9928 - precision_1: 0.9306 - recall_1: 0.8768 - true_positives_1: 4384.0000 - true_negatives_1: 144673.0000 - false_positives_1: 327.0000 - false_negatives_1: 616.0000 - cohen_kappa: 0.8956 - f1_score: 0.8972 - val_loss: 0.4089 - val_accuracy: 0.8980 - val_categorical_accuracy: 0.8980 - val_auc_1: 0.9869 - val_precision_1: 0.9113 - val_recall_1: 0.8920 - val_true_positives_1: 2230.0000 - val_true_negatives_1: 72283.0000 - val_false_positives_1: 217.0000 - val_false_negatives_1: 270.0000 - val_cohen_kappa: 0.8942 - val_f1_score: 0.8858 - lr: 0.0010
# Epoch 2/30
# 313/312 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9300 - categorical_accuracy: 0.9300 - auc_1: 0.9948 - precision_1: 0.9447 - recall_1: 0.9162 - true_positives_1: 4581.0000 - true_negatives_1: 144732.0000 - false_positives_1: 268.0000 - false_negatives_1: 419.0000 - cohen_kappa: 0.9273 - f1_score: 0.9280
# Epoch 2: val_accuracy improved from 0.89800 to 0.91400, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 79s 252ms/step - loss: 0.2521 - accuracy: 0.9300 - categorical_accuracy: 0.9300 - auc_1: 0.9948 - precision_1: 0.9447 - recall_1: 0.9162 - true_positives_1: 4581.0000 - true_negatives_1: 144732.0000 - false_positives_1: 268.0000 - false_negatives_1: 419.0000 - cohen_kappa: 0.9273 - f1_score: 0.9280 - val_loss: 0.3503 - val_accuracy: 0.9140 - val_categorical_accuracy: 0.9140 - val_auc_1: 0.9889 - val_precision_1: 0.9231 - val_recall_1: 0.9080 - val_true_positives_1: 2270.0000 - val_true_negatives_1: 72311.0000 - val_false_positives_1: 189.0000 - val_false_negatives_1: 230.0000 - val_cohen_kappa: 0.9108 - val_f1_score: 0.9116 - lr: 0.0010
# Epoch 3/30
# 313/312 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.9272 - categorical_accuracy: 0.9272 - auc_1: 0.9960 - precision_1: 0.9429 - recall_1: 0.9148 - true_positives_1: 4574.0000 - true_negatives_1: 144723.0000 - false_positives_1: 277.0000 - false_negatives_1: 426.0000 - cohen_kappa: 0.9244 - f1_score: 0.9255
# Epoch 3: val_accuracy improved from 0.91400 to 0.91760, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 78s 250ms/step - loss: 0.2412 - accuracy: 0.9272 - categorical_accuracy: 0.9272 - auc_1: 0.9960 - precision_1: 0.9429 - recall_1: 0.9148 - true_positives_1: 4574.0000 - true_negatives_1: 144723.0000 - false_positives_1: 277.0000 - false_negatives_1: 426.0000 - cohen_kappa: 0.9244 - f1_score: 0.9255 - val_loss: 0.3111 - val_accuracy: 0.9176 - val_categorical_accuracy: 0.9176 - val_auc_1: 0.9922 - val_precision_1: 0.9228 - val_recall_1: 0.9080 - val_true_positives_1: 2270.0000 - val_true_negatives_1: 72310.0000 - val_false_positives_1: 190.0000 - val_false_negatives_1: 230.0000 - val_cohen_kappa: 0.9146 - val_f1_score: 0.9149 - lr: 0.0010
# Epoch 4/30
# 313/312 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9452 - categorical_accuracy: 0.9452 - auc_1: 0.9966 - precision_1: 0.9574 - recall_1: 0.9358 - true_positives_1: 4679.0000 - true_negatives_1: 144792.0000 - false_positives_1: 208.0000 - false_negatives_1: 321.0000 - cohen_kappa: 0.9431 - f1_score: 0.9430
# Epoch 4: val_accuracy did not improve from 0.91760
# 312/312 [==============================] - 77s 245ms/step - loss: 0.2023 - accuracy: 0.9452 - categorical_accuracy: 0.9452 - auc_1: 0.9966 - precision_1: 0.9574 - recall_1: 0.9358 - true_positives_1: 4679.0000 - true_negatives_1: 144792.0000 - false_positives_1: 208.0000 - false_negatives_1: 321.0000 - cohen_kappa: 0.9431 - f1_score: 0.9430 - val_loss: 0.3490 - val_accuracy: 0.9020 - val_categorical_accuracy: 0.9020 - val_auc_1: 0.9918 - val_precision_1: 0.9154 - val_recall_1: 0.8912 - val_true_positives_1: 2228.0000 - val_true_negatives_1: 72294.0000 - val_false_positives_1: 206.0000 - val_false_negatives_1: 272.0000 - val_cohen_kappa: 0.8984 - val_f1_score: 0.8958 - lr: 0.0010
# Epoch 5/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9472 - categorical_accuracy: 0.9472 - auc_1: 0.9966 - precision_1: 0.9549 - recall_1: 0.9402 - true_positives_1: 4701.0000 - true_negatives_1: 144778.0000 - false_positives_1: 222.0000 - false_negatives_1: 299.0000 - cohen_kappa: 0.9452 - f1_score: 0.9452
# Epoch 5: val_accuracy improved from 0.91760 to 0.94320, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 80s 257ms/step - loss: 0.1788 - accuracy: 0.9472 - categorical_accuracy: 0.9472 - auc_1: 0.9966 - precision_1: 0.9549 - recall_1: 0.9402 - true_positives_1: 4701.0000 - true_negatives_1: 144778.0000 - false_positives_1: 222.0000 - false_negatives_1: 299.0000 - cohen_kappa: 0.9452 - f1_score: 0.9452 - val_loss: 0.1855 - val_accuracy: 0.9432 - val_categorical_accuracy: 0.9432 - val_auc_1: 0.9959 - val_precision_1: 0.9463 - val_recall_1: 0.9384 - val_true_positives_1: 2346.0000 - val_true_negatives_1: 72367.0000 - val_false_positives_1: 133.0000 - val_false_negatives_1: 154.0000 - val_cohen_kappa: 0.9411 - val_f1_score: 0.9413 - lr: 0.0010
# Epoch 6/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9490 - categorical_accuracy: 0.9490 - auc_1: 0.9969 - precision_1: 0.9580 - recall_1: 0.9444 - true_positives_1: 4722.0000 - true_negatives_1: 144793.0000 - false_positives_1: 207.0000 - false_negatives_1: 278.0000 - cohen_kappa: 0.9471 - f1_score: 0.9459
# Epoch 6: val_accuracy did not improve from 0.94320
# 312/312 [==============================] - 77s 246ms/step - loss: 0.1689 - accuracy: 0.9490 - categorical_accuracy: 0.9490 - auc_1: 0.9969 - precision_1: 0.9580 - recall_1: 0.9444 - true_positives_1: 4722.0000 - true_negatives_1: 144793.0000 - false_positives_1: 207.0000 - false_negatives_1: 278.0000 - cohen_kappa: 0.9471 - f1_score: 0.9459 - val_loss: 0.2225 - val_accuracy: 0.9388 - val_categorical_accuracy: 0.9388 - val_auc_1: 0.9952 - val_precision_1: 0.9473 - val_recall_1: 0.9276 - val_true_positives_1: 2319.0000 - val_true_negatives_1: 72371.0000 - val_false_positives_1: 129.0000 - val_false_negatives_1: 181.0000 - val_cohen_kappa: 0.9365 - val_f1_score: 0.9337 - lr: 0.0010
# Epoch 7/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9578 - categorical_accuracy: 0.9578 - auc_1: 0.9974 - precision_1: 0.9646 - recall_1: 0.9524 - true_positives_1: 4762.0000 - true_negatives_1: 144825.0000 - false_positives_1: 175.0000 - false_negatives_1: 238.0000 - cohen_kappa: 0.9562 - f1_score: 0.9558
# Epoch 7: val_accuracy did not improve from 0.94320
# 312/312 [==============================] - 76s 243ms/step - loss: 0.1457 - accuracy: 0.9578 - categorical_accuracy: 0.9578 - auc_1: 0.9974 - precision_1: 0.9646 - recall_1: 0.9524 - true_positives_1: 4762.0000 - true_negatives_1: 144825.0000 - false_positives_1: 175.0000 - false_negatives_1: 238.0000 - cohen_kappa: 0.9562 - f1_score: 0.9558 - val_loss: 0.2446 - val_accuracy: 0.9224 - val_categorical_accuracy: 0.9224 - val_auc_1: 0.9964 - val_precision_1: 0.9330 - val_recall_1: 0.9132 - val_true_positives_1: 2283.0000 - val_true_negatives_1: 72336.0000 - val_false_positives_1: 164.0000 - val_false_negatives_1: 217.0000 - val_cohen_kappa: 0.9195 - val_f1_score: 0.9187 - lr: 0.0010
# Epoch 8/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.9548 - categorical_accuracy: 0.9548 - auc_1: 0.9974 - precision_1: 0.9638 - recall_1: 0.9480 - true_positives_1: 4740.0000 - true_negatives_1: 144822.0000 - false_positives_1: 178.0000 - false_negatives_1: 260.0000 - cohen_kappa: 0.9531 - f1_score: 0.9539
# Epoch 8: val_accuracy did not improve from 0.94320
# 312/312 [==============================] - 75s 241ms/step - loss: 0.1498 - accuracy: 0.9548 - categorical_accuracy: 0.9548 - auc_1: 0.9974 - precision_1: 0.9638 - recall_1: 0.9480 - true_positives_1: 4740.0000 - true_negatives_1: 144822.0000 - false_positives_1: 178.0000 - false_negatives_1: 260.0000 - cohen_kappa: 0.9531 - f1_score: 0.9539 - val_loss: 0.3237 - val_accuracy: 0.9084 - val_categorical_accuracy: 0.9084 - val_auc_1: 0.9936 - val_precision_1: 0.9279 - val_recall_1: 0.8900 - val_true_positives_1: 2225.0000 - val_true_negatives_1: 72327.0000 - val_false_positives_1: 173.0000 - val_false_negatives_1: 275.0000 - val_cohen_kappa: 0.9051 - val_f1_score: 0.9065 - lr: 0.0010
# Epoch 9/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9600 - categorical_accuracy: 0.9600 - auc_1: 0.9972 - precision_1: 0.9665 - recall_1: 0.9528 - true_positives_1: 4764.0000 - true_negatives_1: 144835.0000 - false_positives_1: 165.0000 - false_negatives_1: 236.0000 - cohen_kappa: 0.9585 - f1_score: 0.9593
# Epoch 9: val_accuracy did not improve from 0.94320
# 312/312 [==============================] - 75s 239ms/step - loss: 0.1442 - accuracy: 0.9600 - categorical_accuracy: 0.9600 - auc_1: 0.9972 - precision_1: 0.9665 - recall_1: 0.9528 - true_positives_1: 4764.0000 - true_negatives_1: 144835.0000 - false_positives_1: 165.0000 - false_negatives_1: 236.0000 - cohen_kappa: 0.9585 - f1_score: 0.9593 - val_loss: 0.2683 - val_accuracy: 0.9180 - val_categorical_accuracy: 0.9180 - val_auc_1: 0.9943 - val_precision_1: 0.9255 - val_recall_1: 0.9140 - val_true_positives_1: 2285.0000 - val_true_negatives_1: 72316.0000 - val_false_positives_1: 184.0000 - val_false_negatives_1: 215.0000 - val_cohen_kappa: 0.9149 - val_f1_score: 0.9098 - lr: 0.0010
# Epoch 10/30
# 313/312 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9632 - categorical_accuracy: 0.9632 - auc_1: 0.9981 - precision_1: 0.9702 - recall_1: 0.9574 - true_positives_1: 4787.0000 - true_negatives_1: 144853.0000 - false_positives_1: 147.0000 - false_negatives_1: 213.0000 - cohen_kappa: 0.9618 - f1_score: 0.9631
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 10: val_accuracy did not improve from 0.94320
# 312/312 [==============================] - 75s 238ms/step - loss: 0.1159 - accuracy: 0.9632 - categorical_accuracy: 0.9632 - auc_1: 0.9981 - precision_1: 0.9702 - recall_1: 0.9574 - true_positives_1: 4787.0000 - true_negatives_1: 144853.0000 - false_positives_1: 147.0000 - false_negatives_1: 213.0000 - cohen_kappa: 0.9618 - f1_score: 0.9631 - val_loss: 0.2603 - val_accuracy: 0.9316 - val_categorical_accuracy: 0.9316 - val_auc_1: 0.9938 - val_precision_1: 0.9343 - val_recall_1: 0.9272 - val_true_positives_1: 2318.0000 - val_true_negatives_1: 72337.0000 - val_false_positives_1: 163.0000 - val_false_negatives_1: 182.0000 - val_cohen_kappa: 0.9291 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 11/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9818 - categorical_accuracy: 0.9818 - auc_1: 0.9990 - precision_1: 0.9847 - recall_1: 0.9804 - true_positives_1: 4902.0000 - true_negatives_1: 144924.0000 - false_positives_1: 76.0000 - false_negatives_1: 98.0000 - cohen_kappa: 0.9811 - f1_score: 0.9810
# Epoch 11: val_accuracy improved from 0.94320 to 0.97120, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 77s 246ms/step - loss: 0.0633 - accuracy: 0.9818 - categorical_accuracy: 0.9818 - auc_1: 0.9990 - precision_1: 0.9847 - recall_1: 0.9804 - true_positives_1: 4902.0000 - true_negatives_1: 144924.0000 - false_positives_1: 76.0000 - false_negatives_1: 98.0000 - cohen_kappa: 0.9811 - f1_score: 0.9810 - val_loss: 0.0988 - val_accuracy: 0.9712 - val_categorical_accuracy: 0.9712 - val_auc_1: 0.9978 - val_precision_1: 0.9739 - val_recall_1: 0.9700 - val_true_positives_1: 2425.0000 - val_true_negatives_1: 72435.0000 - val_false_positives_1: 65.0000 - val_false_negatives_1: 75.0000 - val_cohen_kappa: 0.9701 - val_f1_score: 0.9679 - lr: 1.0000e-04
# Epoch 12/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9944 - categorical_accuracy: 0.9944 - auc_1: 0.9999 - precision_1: 0.9954 - recall_1: 0.9936 - true_positives_1: 4968.0000 - true_negatives_1: 144977.0000 - false_positives_1: 23.0000 - false_negatives_1: 32.0000 - cohen_kappa: 0.9942 - f1_score: 0.9938
# Epoch 12: val_accuracy improved from 0.97120 to 0.97480, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 77s 247ms/step - loss: 0.0157 - accuracy: 0.9944 - categorical_accuracy: 0.9944 - auc_1: 0.9999 - precision_1: 0.9954 - recall_1: 0.9936 - true_positives_1: 4968.0000 - true_negatives_1: 144977.0000 - false_positives_1: 23.0000 - false_negatives_1: 32.0000 - cohen_kappa: 0.9942 - f1_score: 0.9938 - val_loss: 0.0808 - val_accuracy: 0.9748 - val_categorical_accuracy: 0.9748 - val_auc_1: 0.9985 - val_precision_1: 0.9756 - val_recall_1: 0.9748 - val_true_positives_1: 2437.0000 - val_true_negatives_1: 72439.0000 - val_false_positives_1: 61.0000 - val_false_negatives_1: 63.0000 - val_cohen_kappa: 0.9739 - val_f1_score: 0.9710 - lr: 1.0000e-04
# Epoch 13/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9960 - categorical_accuracy: 0.9960 - auc_1: 1.0000 - precision_1: 0.9966 - recall_1: 0.9954 - true_positives_1: 4977.0000 - true_negatives_1: 144983.0000 - false_positives_1: 17.0000 - false_negatives_1: 23.0000 - cohen_kappa: 0.9958 - f1_score: 0.9961
# Epoch 13: val_accuracy improved from 0.97480 to 0.97720, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 77s 245ms/step - loss: 0.0127 - accuracy: 0.9960 - categorical_accuracy: 0.9960 - auc_1: 1.0000 - precision_1: 0.9966 - recall_1: 0.9954 - true_positives_1: 4977.0000 - true_negatives_1: 144983.0000 - false_positives_1: 17.0000 - false_negatives_1: 23.0000 - cohen_kappa: 0.9958 - f1_score: 0.9961 - val_loss: 0.1071 - val_accuracy: 0.9772 - val_categorical_accuracy: 0.9772 - val_auc_1: 0.9963 - val_precision_1: 0.9791 - val_recall_1: 0.9764 - val_true_positives_1: 2441.0000 - val_true_negatives_1: 72448.0000 - val_false_positives_1: 52.0000 - val_false_negatives_1: 59.0000 - val_cohen_kappa: 0.9764 - val_f1_score: 0.9737 - lr: 1.0000e-04
# Epoch 14/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9970 - categorical_accuracy: 0.9970 - auc_1: 1.0000 - precision_1: 0.9976 - recall_1: 0.9970 - true_positives_1: 4985.0000 - true_negatives_1: 144988.0000 - false_positives_1: 12.0000 - false_negatives_1: 15.0000 - cohen_kappa: 0.9969 - f1_score: 0.9971
# Epoch 14: val_accuracy did not improve from 0.97720
# 312/312 [==============================] - 76s 242ms/step - loss: 0.0096 - accuracy: 0.9970 - categorical_accuracy: 0.9970 - auc_1: 1.0000 - precision_1: 0.9976 - recall_1: 0.9970 - true_positives_1: 4985.0000 - true_negatives_1: 144988.0000 - false_positives_1: 12.0000 - false_negatives_1: 15.0000 - cohen_kappa: 0.9969 - f1_score: 0.9971 - val_loss: 0.1071 - val_accuracy: 0.9756 - val_categorical_accuracy: 0.9756 - val_auc_1: 0.9959 - val_precision_1: 0.9760 - val_recall_1: 0.9744 - val_true_positives_1: 2436.0000 - val_true_negatives_1: 72440.0000 - val_false_positives_1: 60.0000 - val_false_negatives_1: 64.0000 - val_cohen_kappa: 0.9747 - val_f1_score: 0.9721 - lr: 1.0000e-04
# Epoch 15/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9974 - categorical_accuracy: 0.9974 - auc_1: 1.0000 - precision_1: 0.9978 - recall_1: 0.9968 - true_positives_1: 4984.0000 - true_negatives_1: 144989.0000 - false_positives_1: 11.0000 - false_negatives_1: 16.0000 - cohen_kappa: 0.9973 - f1_score: 0.9973
# Epoch 15: val_accuracy did not improve from 0.97720
# 312/312 [==============================] - 75s 240ms/step - loss: 0.0063 - accuracy: 0.9974 - categorical_accuracy: 0.9974 - auc_1: 1.0000 - precision_1: 0.9978 - recall_1: 0.9968 - true_positives_1: 4984.0000 - true_negatives_1: 144989.0000 - false_positives_1: 11.0000 - false_negatives_1: 16.0000 - cohen_kappa: 0.9973 - f1_score: 0.9973 - val_loss: 0.0999 - val_accuracy: 0.9764 - val_categorical_accuracy: 0.9764 - val_auc_1: 0.9973 - val_precision_1: 0.9780 - val_recall_1: 0.9760 - val_true_positives_1: 2440.0000 - val_true_negatives_1: 72445.0000 - val_false_positives_1: 55.0000 - val_false_negatives_1: 60.0000 - val_cohen_kappa: 0.9755 - val_f1_score: 0.9737 - lr: 1.0000e-04
# Epoch 16/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9994
# Epoch 16: val_accuracy improved from 0.97720 to 0.97960, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 77s 246ms/step - loss: 0.0031 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9994 - val_loss: 0.0897 - val_accuracy: 0.9796 - val_categorical_accuracy: 0.9796 - val_auc_1: 0.9973 - val_precision_1: 0.9804 - val_recall_1: 0.9796 - val_true_positives_1: 2449.0000 - val_true_negatives_1: 72451.0000 - val_false_positives_1: 49.0000 - val_false_negatives_1: 51.0000 - val_cohen_kappa: 0.9788 - val_f1_score: 0.9766 - lr: 1.0000e-04
# Epoch 17/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9982 - categorical_accuracy: 0.9982 - auc_1: 1.0000 - precision_1: 0.9982 - recall_1: 0.9978 - true_positives_1: 4989.0000 - true_negatives_1: 144991.0000 - false_positives_1: 9.0000 - false_negatives_1: 11.0000 - cohen_kappa: 0.9981 - f1_score: 0.9982
# Epoch 17: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 77s 245ms/step - loss: 0.0055 - accuracy: 0.9982 - categorical_accuracy: 0.9982 - auc_1: 1.0000 - precision_1: 0.9982 - recall_1: 0.9978 - true_positives_1: 4989.0000 - true_negatives_1: 144991.0000 - false_positives_1: 9.0000 - false_negatives_1: 11.0000 - cohen_kappa: 0.9981 - f1_score: 0.9982 - val_loss: 0.1097 - val_accuracy: 0.9756 - val_categorical_accuracy: 0.9756 - val_auc_1: 0.9956 - val_precision_1: 0.9760 - val_recall_1: 0.9756 - val_true_positives_1: 2439.0000 - val_true_negatives_1: 72440.0000 - val_false_positives_1: 60.0000 - val_false_negatives_1: 61.0000 - val_cohen_kappa: 0.9747 - val_f1_score: 0.9719 - lr: 1.0000e-04
# Epoch 18/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9992 - true_positives_1: 4996.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 4.0000 - cohen_kappa: 0.9994 - f1_score: 0.9993
# Epoch 18: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 242ms/step - loss: 0.0029 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9992 - true_positives_1: 4996.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 4.0000 - cohen_kappa: 0.9994 - f1_score: 0.9993 - val_loss: 0.1153 - val_accuracy: 0.9748 - val_categorical_accuracy: 0.9748 - val_auc_1: 0.9962 - val_precision_1: 0.9756 - val_recall_1: 0.9744 - val_true_positives_1: 2436.0000 - val_true_negatives_1: 72439.0000 - val_false_positives_1: 61.0000 - val_false_negatives_1: 64.0000 - val_cohen_kappa: 0.9739 - val_f1_score: 0.9716 - lr: 1.0000e-04
# Epoch 19/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9982 - categorical_accuracy: 0.9982 - auc_1: 0.9999 - precision_1: 0.9984 - recall_1: 0.9982 - true_positives_1: 4991.0000 - true_negatives_1: 144992.0000 - false_positives_1: 8.0000 - false_negatives_1: 9.0000 - cohen_kappa: 0.9981 - f1_score: 0.9982
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 19: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 77s 245ms/step - loss: 0.0057 - accuracy: 0.9982 - categorical_accuracy: 0.9982 - auc_1: 0.9999 - precision_1: 0.9984 - recall_1: 0.9982 - true_positives_1: 4991.0000 - true_negatives_1: 144992.0000 - false_positives_1: 8.0000 - false_negatives_1: 9.0000 - cohen_kappa: 0.9981 - f1_score: 0.9982 - val_loss: 0.0840 - val_accuracy: 0.9788 - val_categorical_accuracy: 0.9788 - val_auc_1: 0.9979 - val_precision_1: 0.9800 - val_recall_1: 0.9784 - val_true_positives_1: 2446.0000 - val_true_negatives_1: 72450.0000 - val_false_positives_1: 50.0000 - val_false_negatives_1: 54.0000 - val_cohen_kappa: 0.9780 - val_f1_score: 0.9757 - lr: 1.0000e-04
# Epoch 20/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9984 - categorical_accuracy: 0.9984 - auc_1: 1.0000 - precision_1: 0.9984 - recall_1: 0.9984 - true_positives_1: 4992.0000 - true_negatives_1: 144992.0000 - false_positives_1: 8.0000 - false_negatives_1: 8.0000 - cohen_kappa: 0.9983 - f1_score: 0.9984
# Epoch 20: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 243ms/step - loss: 0.0045 - accuracy: 0.9984 - categorical_accuracy: 0.9984 - auc_1: 1.0000 - precision_1: 0.9984 - recall_1: 0.9984 - true_positives_1: 4992.0000 - true_negatives_1: 144992.0000 - false_positives_1: 8.0000 - false_negatives_1: 8.0000 - cohen_kappa: 0.9983 - f1_score: 0.9984 - val_loss: 0.0972 - val_accuracy: 0.9796 - val_categorical_accuracy: 0.9796 - val_auc_1: 0.9967 - val_precision_1: 0.9796 - val_recall_1: 0.9788 - val_true_positives_1: 2447.0000 - val_true_negatives_1: 72449.0000 - val_false_positives_1: 51.0000 - val_false_negatives_1: 53.0000 - val_cohen_kappa: 0.9788 - val_f1_score: 0.9774 - lr: 1.0000e-05
# Epoch 21/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9988 - categorical_accuracy: 0.9988 - auc_1: 1.0000 - precision_1: 0.9988 - recall_1: 0.9988 - true_positives_1: 4994.0000 - true_negatives_1: 144994.0000 - false_positives_1: 6.0000 - false_negatives_1: 6.0000 - cohen_kappa: 0.9988 - f1_score: 0.9989
# Epoch 21: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 242ms/step - loss: 0.0038 - accuracy: 0.9988 - categorical_accuracy: 0.9988 - auc_1: 1.0000 - precision_1: 0.9988 - recall_1: 0.9988 - true_positives_1: 4994.0000 - true_negatives_1: 144994.0000 - false_positives_1: 6.0000 - false_negatives_1: 6.0000 - cohen_kappa: 0.9988 - f1_score: 0.9989 - val_loss: 0.0760 - val_accuracy: 0.9784 - val_categorical_accuracy: 0.9784 - val_auc_1: 0.9981 - val_precision_1: 0.9792 - val_recall_1: 0.9780 - val_true_positives_1: 2445.0000 - val_true_negatives_1: 72448.0000 - val_false_positives_1: 52.0000 - val_false_negatives_1: 55.0000 - val_cohen_kappa: 0.9776 - val_f1_score: 0.9761 - lr: 1.0000e-05
# Epoch 22/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996 - categorical_accuracy: 0.9996 - auc_1: 1.0000 - precision_1: 0.9996 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144998.0000 - false_positives_1: 2.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9996 - f1_score: 0.9996
# Epoch 22: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 77s 245ms/step - loss: 0.0021 - accuracy: 0.9996 - categorical_accuracy: 0.9996 - auc_1: 1.0000 - precision_1: 0.9996 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144998.0000 - false_positives_1: 2.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9996 - f1_score: 0.9996 - val_loss: 0.0869 - val_accuracy: 0.9784 - val_categorical_accuracy: 0.9784 - val_auc_1: 0.9975 - val_precision_1: 0.9784 - val_recall_1: 0.9772 - val_true_positives_1: 2443.0000 - val_true_negatives_1: 72446.0000 - val_false_positives_1: 54.0000 - val_false_negatives_1: 57.0000 - val_cohen_kappa: 0.9776 - val_f1_score: 0.9751 - lr: 1.0000e-05
# Epoch 23/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9992 - categorical_accuracy: 0.9992 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9992 - f1_score: 0.9992
# Epoch 23: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 244ms/step - loss: 0.0021 - accuracy: 0.9992 - categorical_accuracy: 0.9992 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9992 - f1_score: 0.9992 - val_loss: 0.0993 - val_accuracy: 0.9772 - val_categorical_accuracy: 0.9772 - val_auc_1: 0.9963 - val_precision_1: 0.9772 - val_recall_1: 0.9764 - val_true_positives_1: 2441.0000 - val_true_negatives_1: 72443.0000 - val_false_positives_1: 57.0000 - val_false_negatives_1: 59.0000 - val_cohen_kappa: 0.9764 - val_f1_score: 0.9738 - lr: 1.0000e-05
# Epoch 24/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992 - categorical_accuracy: 0.9992 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9992 - f1_score: 0.9992
# Epoch 24: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 75s 240ms/step - loss: 0.0026 - accuracy: 0.9992 - categorical_accuracy: 0.9992 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9992 - f1_score: 0.9992 - val_loss: 0.0891 - val_accuracy: 0.9788 - val_categorical_accuracy: 0.9788 - val_auc_1: 0.9973 - val_precision_1: 0.9788 - val_recall_1: 0.9784 - val_true_positives_1: 2446.0000 - val_true_negatives_1: 72447.0000 - val_false_positives_1: 53.0000 - val_false_negatives_1: 54.0000 - val_cohen_kappa: 0.9780 - val_f1_score: 0.9758 - lr: 1.0000e-05
# Epoch 25/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9994
# Epoch 25: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 77s 246ms/step - loss: 0.0019 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9994 - val_loss: 0.0769 - val_accuracy: 0.9796 - val_categorical_accuracy: 0.9796 - val_auc_1: 0.9979 - val_precision_1: 0.9800 - val_recall_1: 0.9792 - val_true_positives_1: 2448.0000 - val_true_negatives_1: 72450.0000 - val_false_positives_1: 50.0000 - val_false_negatives_1: 52.0000 - val_cohen_kappa: 0.9788 - val_f1_score: 0.9765 - lr: 1.0000e-05
# Epoch 26/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998 - categorical_accuracy: 0.9998 - auc_1: 1.0000 - precision_1: 0.9998 - recall_1: 0.9998 - true_positives_1: 4999.0000 - true_negatives_1: 144999.0000 - false_positives_1: 1.0000 - false_negatives_1: 1.0000 - cohen_kappa: 0.9998 - f1_score: 0.9998
# Epoch 26: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 244ms/step - loss: 0.0014 - accuracy: 0.9998 - categorical_accuracy: 0.9998 - auc_1: 1.0000 - precision_1: 0.9998 - recall_1: 0.9998 - true_positives_1: 4999.0000 - true_negatives_1: 144999.0000 - false_positives_1: 1.0000 - false_negatives_1: 1.0000 - cohen_kappa: 0.9998 - f1_score: 0.9998 - val_loss: 0.1000 - val_accuracy: 0.9788 - val_categorical_accuracy: 0.9788 - val_auc_1: 0.9965 - val_precision_1: 0.9788 - val_recall_1: 0.9780 - val_true_positives_1: 2445.0000 - val_true_negatives_1: 72447.0000 - val_false_positives_1: 53.0000 - val_false_negatives_1: 55.0000 - val_cohen_kappa: 0.9780 - val_f1_score: 0.9756 - lr: 1.0000e-05
# Epoch 27/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9995
# Epoch 27: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 244ms/step - loss: 0.0017 - accuracy: 0.9994 - categorical_accuracy: 0.9994 - auc_1: 1.0000 - precision_1: 0.9994 - recall_1: 0.9994 - true_positives_1: 4997.0000 - true_negatives_1: 144997.0000 - false_positives_1: 3.0000 - false_negatives_1: 3.0000 - cohen_kappa: 0.9994 - f1_score: 0.9995 - val_loss: 0.0856 - val_accuracy: 0.9792 - val_categorical_accuracy: 0.9792 - val_auc_1: 0.9973 - val_precision_1: 0.9792 - val_recall_1: 0.9784 - val_true_positives_1: 2446.0000 - val_true_negatives_1: 72448.0000 - val_false_positives_1: 52.0000 - val_false_negatives_1: 54.0000 - val_cohen_kappa: 0.9784 - val_f1_score: 0.9762 - lr: 1.0000e-05
# Epoch 28/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9990 - categorical_accuracy: 0.9990 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9990 - f1_score: 0.9990
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 28: val_accuracy did not improve from 0.97960
# 312/312 [==============================] - 76s 244ms/step - loss: 0.0031 - accuracy: 0.9990 - categorical_accuracy: 0.9990 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9990 - true_positives_1: 4995.0000 - true_negatives_1: 144996.0000 - false_positives_1: 4.0000 - false_negatives_1: 5.0000 - cohen_kappa: 0.9990 - f1_score: 0.9990 - val_loss: 0.0777 - val_accuracy: 0.9796 - val_categorical_accuracy: 0.9796 - val_auc_1: 0.9983 - val_precision_1: 0.9796 - val_recall_1: 0.9796 - val_true_positives_1: 2449.0000 - val_true_negatives_1: 72449.0000 - val_false_positives_1: 51.0000 - val_false_negatives_1: 51.0000 - val_cohen_kappa: 0.9788 - val_f1_score: 0.9768 - lr: 1.0000e-05
# Epoch 29/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998 - categorical_accuracy: 0.9998 - auc_1: 1.0000 - precision_1: 0.9998 - recall_1: 0.9996 - true_positives_1: 4998.0000 - true_negatives_1: 144999.0000 - false_positives_1: 1.0000 - false_negatives_1: 2.0000 - cohen_kappa: 0.9998 - f1_score: 0.9998
# Epoch 29: val_accuracy improved from 0.97960 to 0.98040, saving model to Best_DenseNet201_v23.h5
# 312/312 [==============================] - 76s 244ms/step - loss: 0.0015 - accuracy: 0.9998 - categorical_accuracy: 0.9998 - auc_1: 1.0000 - precision_1: 0.9998 - recall_1: 0.9996 - true_positives_1: 4998.0000 - true_negatives_1: 144999.0000 - false_positives_1: 1.0000 - false_negatives_1: 2.0000 - cohen_kappa: 0.9998 - f1_score: 0.9998 - val_loss: 0.0725 - val_accuracy: 0.9804 - val_categorical_accuracy: 0.9804 - val_auc_1: 0.9981 - val_precision_1: 0.9808 - val_recall_1: 0.9804 - val_true_positives_1: 2451.0000 - val_true_negatives_1: 72452.0000 - val_false_positives_1: 48.0000 - val_false_negatives_1: 49.0000 - val_cohen_kappa: 0.9797 - val_f1_score: 0.9782 - lr: 1.0000e-05
# Epoch 30/30
# 313/312 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996 - categorical_accuracy: 0.9996 - auc_1: 1.0000 - precision_1: 0.9996 - recall_1: 0.9996 - true_positives_1: 4998.0000 - true_negatives_1: 144998.0000 - false_positives_1: 2.0000 - false_negatives_1: 2.0000 - cohen_kappa: 0.9996 - f1_score: 0.9996
# Epoch 30: val_accuracy did not improve from 0.98040
# 312/312 [==============================] - 76s 242ms/step - loss: 0.0014 - accuracy: 0.9996 - categorical_accuracy: 0.9996 - auc_1: 1.0000 - precision_1: 0.9996 - recall_1: 0.9996 - true_positives_1: 4998.0000 - true_negatives_1: 144998.0000 - false_positives_1: 2.0000 - false_negatives_1: 2.0000 - cohen_kappa: 0.9996 - f1_score: 0.9996 - val_loss: 0.0900 - val_accuracy: 0.9800 - val_categorical_accuracy: 0.9800 - val_auc_1: 0.9971 - val_precision_1: 0.9804 - val_recall_1: 0.9796 - val_true_positives_1: 2449.0000 - val_true_negatives_1: 72451.0000 - val_false_positives_1: 49.0000 - val_false_negatives_1: 51.0000 - val_cohen_kappa: 0.9793 - val_f1_score: 0.9774 - lr: 1.0000e-05

# %%
evaluate_(final_model, generator_test)
# Out:
# 157/157 [==============================] - 20s 128ms/step - loss: 0.0900 - accuracy: 0.9800 - categorical_accuracy: 0.9800 - auc_1: 0.9971 - precision_1: 0.9804 - recall_1: 0.9796 - true_positives_1: 2449.0000 - true_negatives_1: 72451.0000 - false_positives_1: 49.0000 - false_negatives_1: 51.0000 - cohen_kappa: 0.9793 - f1_score: 0.9774
# 157/157 [==============================] - 20s 130ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00       153
#            2       0.93      1.00      0.97        84
#            3       0.97      1.00      0.99        72
#            4       1.00      1.00      1.00       124
#            5       1.00      1.00      1.00        47
#            6       1.00      1.00      1.00        99
#            7       0.94      1.00      0.97        84
#            8       1.00      0.62      0.77        66
#            9       1.00      1.00      1.00        84
#           10       1.00      0.99      0.99        78
#           11       0.87      1.00      0.93        75
#           12       1.00      1.00      1.00        85
#           13       0.93      1.00      0.96       126
#           14       1.00      1.00      1.00        92
#           15       1.00      1.00      1.00        89
#           16       1.00      0.98      0.99        82
#           17       1.00      1.00      1.00        66
#           18       1.00      1.00      1.00        41
#           19       0.98      0.82      0.90        78
#           20       1.00      1.00      1.00        79
#           21       0.83      0.99      0.90        71
#           22       1.00      1.00      1.00        77
#           23       1.00      1.00      1.00        89
#           24       0.99      1.00      0.99        94
#           25       1.00      1.00      1.00        90
#           26       1.00      1.00      1.00        57
#           27       1.00      1.00      1.00        87
#           28       1.00      0.93      0.97       105
#           29       1.00      1.00      1.00        70
#
#     accuracy                           0.98      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
# /tmp/ipykernel_42/2485669865.py:45: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import time
import numpy as np
from PIL import Image  # Add this import statement

# Load a JPEG image
image_path = '/kaggle/input/leaf-dataset/augmented/val/Amaranthus Viridis (Arive-Dantu)/Amaranthus Viridis (Arive-Dantu)_original_AV-S-015.jpg_12e7805c-4aff-4f26-9f50-c89504450078.jpg'
test_image = Image.open(image_path)

# Depending on your model's input requirements, you might need to preprocess the image
# For example, if your model expects a specific input size:
target_size = (112, 112)  # Adjust this based on your model's input size
test_image = test_image.resize(target_size)
test_image_array = np.array(test_image)  # Convert to NumPy array if needed

# Repeat inference for a certain number of iterations to get an average time
num_iterations = 100
total_time = 0

for _ in range(num_iterations):
    start_time = time.time()
    predictions = final_model.predict(np.expand_dims(test_image_array, axis=0))
    end_time = time.time()
    inference_time = end_time - start_time
    total_time += inference_time

# Calculate average inference time
average_inference_time = total_time / num_iterations

# Calculate inference speed (predictions per second)
inference_speed = 1 / average_inference_time

print(f"Average Inference Time: {average_inference_time:.5f} seconds")
print(f"Inference Speed: {inference_speed:.2f} predictions per second")
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# Average Inference Time: 0.11683 seconds
# Inference Speed: 8.56 predictions per second

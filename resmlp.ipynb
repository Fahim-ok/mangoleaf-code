# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tensorflow import keras
import seaborn as sns
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Flatten, Reshape, Conv2DTranspose, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.utils import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

np.random.seed(72)
tf.random.set_seed(72)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    
    # ROC curve
    plt.subplot(1, 2, 2)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(len(class_labels)):
        fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    for i in range(len(class_labels)):
        plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

# Call the function with your model and test generator

# %%
train_dir = r"/kaggle/input/mango-leaf/mango-prepo/train"
test_dir = r"/kaggle/input/mango-leaf/mango-prepo/test"
datagen_train = ImageDataGenerator(rescale=1./255,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  horizontal_flip=True,
                                  vertical_flip=False)


datagen_test = ImageDataGenerator(rescale=1./255)


batch_size = 16
generator_train = datagen_train.flow_from_directory(directory=train_dir,
                                                    target_size=(112, 112),
                                                    batch_size=batch_size,
                                                    shuffle=True)

generator_test = datagen_test.flow_from_directory(directory=test_dir,
                                                  target_size=(112, 112),
                                                  batch_size=batch_size,
                                                  shuffle=False)
# Calculate class weights
labels = generator_train.classes
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)
class_weights = dict(zip(np.unique(labels), class_weights))
print(class_weights)
# Out:
# Found 13307 images belonging to 26 classes.
# Found 1684 images belonging to 26 classes.
# {0: 1.0640492563569486, 1: 1.0662660256410257, 2: 1.0662660256410257, 3: 1.0402595372107568, 4: 1.2273565762774397, 5: 1.0381494772975504, 6: 1.053102247546692, 7: 1.2795192307692307, 8: 1.0487862547288778, 9: 1.053102247546692, 10: 0.6486789509603198, 11: 1.0662660256410257, 12: 1.4623076923076923, 13: 0.8809082483781279, 14: 0.7571119708693673, 15: 1.0466414975617429, 16: 1.7527660695468914, 17: 0.5415954415954416, 18: 1.0662660256410257, 19: 0.9042538733351454, 20: 0.789826685660019, 21: 1.5462468045549616, 22: 1.0256667180514876, 23: 1.8085077466702908, 24: 1.0445054945054946, 25: 0.7259683578832515}

# %%
# !pip install keras_cv_attention_models
# Out:
# Requirement already satisfied: keras_cv_attention_models in /opt/conda/lib/python3.10/site-packages (1.3.21)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (9.5.0)
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (6.1.1)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (2023.6.3)
# Requirement already satisfied: tensorflow-datasets in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (4.9.2)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from keras_cv_attention_models) (2.12.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/conda/lib/python3.10/site-packages (from ftfy->keras_cv_attention_models) (0.2.6)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.4.13)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->keras_cv_attention_models) (0.32.0)
# Requirement already satisfied: array-record in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.4.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (8.1.7)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.1.8)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (1.3.0)
# Requirement already satisfied: promise in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (2.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (5.9.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (2.31.0)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.14.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (0.10.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv_attention_models) (4.66.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->keras_cv_attention_models) (0.40.0)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras_cv_attention_models) (5.12.0)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->keras_cv_attention_models) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow->keras_cv_attention_models) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow->keras_cv_attention_models) (1.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->tensorflow-datasets->keras_cv_attention_models) (2023.7.22)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (2.3.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow->keras_cv_attention_models) (3.0.9)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.10/site-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv_attention_models) (1.59.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras_cv_attention_models) (3.2.2)

# %%
from keras_cv_attention_models import coatnet
mm = coatnet.CoAtNet0(input_shape=(112, 112, 3), pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/coatnet/coatnet0_160_imagenet.h5
# 93670048/93670048 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/coatnet0_160_imagenet.h5
# >>>> Reload mismatched weights: 160 -> (112, 112)
# >>>> Reload layer: stack_3_block_1_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_2_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_3_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_4_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_5_mhsa_pos_emb
# >>>> Reload layer: stack_4_block_1_mhsa_pos_emb
# >>>> Reload layer: stack_4_block_2_mhsa_pos_emb

# %%
from keras_cv_attention_models import coatnet
mm = coatnet.CoAtNet0(input_shape=(112, 112, 3), pretrained="imagenet")

# %%
from keras_cv_attention_models import res_mlp
# mm = res_mlp.ResMLP12()

# %%
mm = res_mlp.ResMLP12(input_shape=(112, 112, 3), pretrained="imagenet")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/mlp_family/resmlp12_imagenet.h5
# 61814776/61814776 [==============================] - 0s 0us/step
# >>>> Load pretrained from: /root/.keras/models/resmlp12_imagenet.h5

# %%
from keras_cv_attention_models import wave_mlp
mm = wave_mlp.WaveMLP_T(input_shape=(112, 112, 3), pretrained="imagenet")
# Out:
# >>>> Load pretrained from: /root/.keras/models/wavemlp_t_imagenet.h5

# %%
from keras_cv_attention_models import mobilevit
mm = mobilevit.MobileViTBasePatch16(input_shape=(112, 112, 3))
mm2 = mobilevit.MobileViTBasePatch16(input_shape=(112, 112, 3))

# %%
# mm.summary()

# %%
from keras_cv_attention_models import swin_transformer_v2

# %%
mm2 = swin_transformer_v2.SwinTransformerV2Tiny_window8(input_shape=(112, 112, 3))

# %%
# mm2.summary()

# %%
"""
transfer_layer = mm.get_layer('avg_pool')
conv_model = Model(inputs=mm.input, outputs=transfer_layer.output)
"""

# %%
"""
#for layer in conv_model.layers:
#    layer.trainable = False
    
# Start a new Keras Sequential model.
new_model = Sequential()

# Add the convolutional part of the VGG16 model from above.
new_model.add(conv_model)


# Add the final layer for the actual classification.
new_model.add(Dense(2, activation='softmax'))
"""

# %%
from keras_cv_attention_models import beit
mm2 = beit.BeitBasePatch16(input_shape=(112, 112, 3))

# %%
mm_last_layer = mm.get_layer('global_average_pooling1d').output
#out = Dense(256, activation='relu', name='dense_1')(mm_last_layer)
#out = Dense(11, activation='softmax', name='prediction1')(out)
mm_custom = Model(mm.input, mm_last_layer)

# %%
mm2_last_layer = mm2.get_layer('out_ln').output
#out2 = Dense(256, activation='relu', name='dense_1')(mm2_last_layer)
#out2 = Dense(11, activation='softmax', name='prediction1')(out2)
mm2_custom = Model(mm2.input, mm2_last_layer)

# %%
# Define a custom linear attention layer
class LinearAttentionLayer(keras.layers.Layer):
    def __init__(self, units, **kwargs):
        super(LinearAttentionLayer, self).__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        self.W_q = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)
        self.W_k = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)
        self.W_v = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)

    def call(self, inputs):
        Q = tf.matmul(inputs, self.W_q)
        K = tf.matmul(inputs, self.W_k)
        V = tf.matmul(inputs, self.W_v)

        attn_scores = tf.matmul(Q, K, transpose_b=True)
        attn_scores = tf.nn.softmax(attn_scores / tf.math.sqrt(tf.cast(self.units, tf.float32)), axis=-1)
        output = tf.matmul(attn_scores, V)

        return output

# ... Continue with your code ...

# Add the attention layer where needed in your model
num_classes = 2
avg_ensemble_model_last_layer = avg_ensemble_model.get_layer('average').output

# Add Linear Attention Layer here (for example, just before the output layer)
attention_output = LinearAttentionLayer(64)(avg_ensemble_model_last_layer)

output_layer = Dense(num_classes, activation='softmax', name='output_1')(attention_output)
final_model = Model(avg_ensemble_model.input, output_layer)

final_model.summary()

# %%
from tensorflow.keras import layers
inputs = keras.Input(shape=(112,112,3))
outputs = layers.average([mm_custom(inputs), mm2_custom(inputs)])

avg_ensemble_model = keras.Model(inputs=inputs, outputs=outputs)
avg_ensemble_model.summary()

# %%
from tensorflow.keras import layers
inputs = keras.Input(shape=(112,112,3))
outputs = layers.average([mm_custom(inputs)])

avg_ensemble_model = keras.Model(inputs=inputs, outputs=outputs)
avg_ensemble_model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  model_4 (Functional)        (None, 384)               14531928
#
#  average_1 (Average)         (None, 384)               0
#
# =================================================================
# Total params: 14,531,928
# Trainable params: 14,531,928
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_classes = 26
avg_ensemble_model_last_layer = avg_ensemble_model.get_layer('average_1').output
output_layer = Dense(num_classes, activation='softmax', name='output_1')(avg_ensemble_model_last_layer)
final_model = Model(avg_ensemble_model.input, output_layer)

final_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  model_4 (Functional)        (None, 384)               14531928
#
#  average_1 (Average)         (None, 384)               0
#
#  output_1 (Dense)            (None, 26)                10010
#
# =================================================================
# Total params: 14,541,938
# Trainable params: 14,541,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(lr=1e-5)
loss = 'categorical_crossentropy'
# metrics = ['categorical_accuracy']
metrics = ['accuracy', 'categorical_accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 
           tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), 
           tf.keras.metrics.FalseNegatives(), tfa.metrics.CohenKappa(num_classes = num_classes), 
           tfa.metrics.F1Score(num_classes = num_classes)]

final_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
import os

# Delete the existing HDF5 file if it exists
if os.path.exists('Best_DenseNet201.h5'):
    os.remove('Best_DenseNet201.h5')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1,
    patience=9, mode="max", min_delta=0.0001, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(filepath='Best_DenseNet201_v23.h5', save_best_only=True, monitor = 'val_accuracy', verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

callbacks = [lr, checkpoint, early_stopping]

# %%
epochs = 30

steps_per_epoch = generator_train.n / batch_size
steps_test = generator_test.n / batch_size

history = final_model.fit_generator(generator=generator_train,
                                  epochs=epochs,
                                  steps_per_epoch=steps_per_epoch,
                                  validation_data=generator_test,
                                  validation_steps=steps_test,
                                   callbacks=callbacks, class_weight =class_weights)
# Out:
# /tmp/ipykernel_32/2027776823.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = final_model.fit_generator(generator=generator_train,
# Epoch 1/30
# 832/831 [==============================] - ETA: 0s - loss: 4.8897 - accuracy: 0.2478 - categorical_accuracy: 0.2478 - auc_2: 0.7686 - precision_2: 0.5336 - recall_2: 0.0942 - true_positives_2: 1254.0000 - true_negatives_2: 331579.0000 - false_positives_2: 1096.0000 - false_negatives_2: 12053.0000 - cohen_kappa: 0.2179 - f1_score: 0.2405
# Epoch 1: val_accuracy improved from -inf to 0.47862, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 259s 275ms/step - loss: 4.8897 - accuracy: 0.2478 - categorical_accuracy: 0.2478 - auc_2: 0.7686 - precision_2: 0.5336 - recall_2: 0.0942 - true_positives_2: 1254.0000 - true_negatives_2: 331579.0000 - false_positives_2: 1096.0000 - false_negatives_2: 12053.0000 - cohen_kappa: 0.2179 - f1_score: 0.2405 - val_loss: 1.8105 - val_accuracy: 0.4786 - val_categorical_accuracy: 0.4786 - val_auc_2: 0.9143 - val_precision_2: 0.8135 - val_recall_2: 0.2643 - val_true_positives_2: 445.0000 - val_true_negatives_2: 41998.0000 - val_false_positives_2: 102.0000 - val_false_negatives_2: 1239.0000 - val_cohen_kappa: 0.4562 - val_f1_score: 0.4389 - lr: 0.0010
# Epoch 2/30
# 832/831 [==============================] - ETA: 0s - loss: 1.8020 - accuracy: 0.4682 - categorical_accuracy: 0.4682 - auc_2: 0.9128 - precision_2: 0.7631 - recall_2: 0.2963 - true_positives_2: 3943.0000 - true_negatives_2: 331451.0000 - false_positives_2: 1224.0000 - false_negatives_2: 9364.0000 - cohen_kappa: 0.4465 - f1_score: 0.4587
# Epoch 2: val_accuracy improved from 0.47862 to 0.59145, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 235s 282ms/step - loss: 1.8020 - accuracy: 0.4682 - categorical_accuracy: 0.4682 - auc_2: 0.9128 - precision_2: 0.7631 - recall_2: 0.2963 - true_positives_2: 3943.0000 - true_negatives_2: 331451.0000 - false_positives_2: 1224.0000 - false_negatives_2: 9364.0000 - cohen_kappa: 0.4465 - f1_score: 0.4587 - val_loss: 1.3674 - val_accuracy: 0.5914 - val_categorical_accuracy: 0.5914 - val_auc_2: 0.9505 - val_precision_2: 0.8077 - val_recall_2: 0.4590 - val_true_positives_2: 773.0000 - val_true_negatives_2: 41916.0000 - val_false_positives_2: 184.0000 - val_false_negatives_2: 911.0000 - val_cohen_kappa: 0.5746 - val_f1_score: 0.5897 - lr: 0.0010
# Epoch 3/30
# 832/831 [==============================] - ETA: 0s - loss: 1.3832 - accuracy: 0.5826 - categorical_accuracy: 0.5826 - auc_2: 0.9487 - precision_2: 0.7772 - recall_2: 0.4411 - true_positives_2: 5870.0000 - true_negatives_2: 330992.0000 - false_positives_2: 1683.0000 - false_negatives_2: 7437.0000 - cohen_kappa: 0.5652 - f1_score: 0.5766
# Epoch 3: val_accuracy improved from 0.59145 to 0.65083, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 230s 276ms/step - loss: 1.3832 - accuracy: 0.5826 - categorical_accuracy: 0.5826 - auc_2: 0.9487 - precision_2: 0.7772 - recall_2: 0.4411 - true_positives_2: 5870.0000 - true_negatives_2: 330992.0000 - false_positives_2: 1683.0000 - false_negatives_2: 7437.0000 - cohen_kappa: 0.5652 - f1_score: 0.5766 - val_loss: 1.1686 - val_accuracy: 0.6508 - val_categorical_accuracy: 0.6508 - val_auc_2: 0.9623 - val_precision_2: 0.8062 - val_recall_2: 0.5410 - val_true_positives_2: 911.0000 - val_true_negatives_2: 41881.0000 - val_false_positives_2: 219.0000 - val_false_negatives_2: 773.0000 - val_cohen_kappa: 0.6363 - val_f1_score: 0.6405 - lr: 0.0010
# Epoch 4/30
# 832/831 [==============================] - ETA: 0s - loss: 1.1486 - accuracy: 0.6475 - categorical_accuracy: 0.6475 - auc_2: 0.9628 - precision_2: 0.7944 - recall_2: 0.5318 - true_positives_2: 7076.0000 - true_negatives_2: 330844.0000 - false_positives_2: 1831.0000 - false_negatives_2: 6231.0000 - cohen_kappa: 0.6327 - f1_score: 0.6427
# Epoch 4: val_accuracy improved from 0.65083 to 0.72268, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 233s 280ms/step - loss: 1.1486 - accuracy: 0.6475 - categorical_accuracy: 0.6475 - auc_2: 0.9628 - precision_2: 0.7944 - recall_2: 0.5318 - true_positives_2: 7076.0000 - true_negatives_2: 330844.0000 - false_positives_2: 1831.0000 - false_negatives_2: 6231.0000 - cohen_kappa: 0.6327 - f1_score: 0.6427 - val_loss: 0.8468 - val_accuracy: 0.7227 - val_categorical_accuracy: 0.7227 - val_auc_2: 0.9807 - val_precision_2: 0.8363 - val_recall_2: 0.6520 - val_true_positives_2: 1098.0000 - val_true_negatives_2: 41885.0000 - val_false_positives_2: 215.0000 - val_false_negatives_2: 586.0000 - val_cohen_kappa: 0.7109 - val_f1_score: 0.7199 - lr: 0.0010
# Epoch 5/30
# 832/831 [==============================] - ETA: 0s - loss: 0.9948 - accuracy: 0.6861 - categorical_accuracy: 0.6861 - auc_2: 0.9719 - precision_2: 0.8025 - recall_2: 0.5886 - true_positives_2: 7832.0000 - true_negatives_2: 330747.0000 - false_positives_2: 1928.0000 - false_negatives_2: 5475.0000 - cohen_kappa: 0.6729 - f1_score: 0.6832
# Epoch 5: val_accuracy did not improve from 0.72268
# 831/831 [==============================] - 229s 275ms/step - loss: 0.9948 - accuracy: 0.6861 - categorical_accuracy: 0.6861 - auc_2: 0.9719 - precision_2: 0.8025 - recall_2: 0.5886 - true_positives_2: 7832.0000 - true_negatives_2: 330747.0000 - false_positives_2: 1928.0000 - false_negatives_2: 5475.0000 - cohen_kappa: 0.6729 - f1_score: 0.6832 - val_loss: 1.1009 - val_accuracy: 0.6586 - val_categorical_accuracy: 0.6586 - val_auc_2: 0.9658 - val_precision_2: 0.7674 - val_recall_2: 0.5778 - val_true_positives_2: 973.0000 - val_true_negatives_2: 41805.0000 - val_false_positives_2: 295.0000 - val_false_negatives_2: 711.0000 - val_cohen_kappa: 0.6437 - val_f1_score: 0.6389 - lr: 0.0010
# Epoch 6/30
# 832/831 [==============================] - ETA: 0s - loss: 0.9204 - accuracy: 0.7104 - categorical_accuracy: 0.7104 - auc_2: 0.9751 - precision_2: 0.8165 - recall_2: 0.6270 - true_positives_2: 8343.0000 - true_negatives_2: 330800.0000 - false_positives_2: 1875.0000 - false_negatives_2: 4964.0000 - cohen_kappa: 0.6981 - f1_score: 0.7087
# Epoch 6: val_accuracy improved from 0.72268 to 0.75831, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 231s 278ms/step - loss: 0.9204 - accuracy: 0.7104 - categorical_accuracy: 0.7104 - auc_2: 0.9751 - precision_2: 0.8165 - recall_2: 0.6270 - true_positives_2: 8343.0000 - true_negatives_2: 330800.0000 - false_positives_2: 1875.0000 - false_negatives_2: 4964.0000 - cohen_kappa: 0.6981 - f1_score: 0.7087 - val_loss: 0.7532 - val_accuracy: 0.7583 - val_categorical_accuracy: 0.7583 - val_auc_2: 0.9816 - val_precision_2: 0.8231 - val_recall_2: 0.7156 - val_true_positives_2: 1205.0000 - val_true_negatives_2: 41841.0000 - val_false_positives_2: 259.0000 - val_false_negatives_2: 479.0000 - val_cohen_kappa: 0.7483 - val_f1_score: 0.7633 - lr: 0.0010
# Epoch 7/30
# 832/831 [==============================] - ETA: 0s - loss: 0.8516 - accuracy: 0.7288 - categorical_accuracy: 0.7288 - auc_2: 0.9780 - precision_2: 0.8222 - recall_2: 0.6483 - true_positives_2: 8627.0000 - true_negatives_2: 330809.0000 - false_positives_2: 1866.0000 - false_negatives_2: 4680.0000 - cohen_kappa: 0.7173 - f1_score: 0.7274
# Epoch 7: val_accuracy did not improve from 0.75831
# 831/831 [==============================] - 226s 271ms/step - loss: 0.8516 - accuracy: 0.7288 - categorical_accuracy: 0.7288 - auc_2: 0.9780 - precision_2: 0.8222 - recall_2: 0.6483 - true_positives_2: 8627.0000 - true_negatives_2: 330809.0000 - false_positives_2: 1866.0000 - false_negatives_2: 4680.0000 - cohen_kappa: 0.7173 - f1_score: 0.7274 - val_loss: 0.7741 - val_accuracy: 0.7565 - val_categorical_accuracy: 0.7565 - val_auc_2: 0.9815 - val_precision_2: 0.8213 - val_recall_2: 0.7067 - val_true_positives_2: 1190.0000 - val_true_negatives_2: 41841.0000 - val_false_positives_2: 259.0000 - val_false_negatives_2: 494.0000 - val_cohen_kappa: 0.7459 - val_f1_score: 0.7491 - lr: 0.0010
# Epoch 8/30
# 832/831 [==============================] - ETA: 0s - loss: 0.8123 - accuracy: 0.7388 - categorical_accuracy: 0.7388 - auc_2: 0.9795 - precision_2: 0.8276 - recall_2: 0.6669 - true_positives_2: 8874.0000 - true_negatives_2: 330826.0000 - false_positives_2: 1849.0000 - false_negatives_2: 4433.0000 - cohen_kappa: 0.7277 - f1_score: 0.7382
# Epoch 8: val_accuracy improved from 0.75831 to 0.81888, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 232s 279ms/step - loss: 0.8123 - accuracy: 0.7388 - categorical_accuracy: 0.7388 - auc_2: 0.9795 - precision_2: 0.8276 - recall_2: 0.6669 - true_positives_2: 8874.0000 - true_negatives_2: 330826.0000 - false_positives_2: 1849.0000 - false_negatives_2: 4433.0000 - cohen_kappa: 0.7277 - f1_score: 0.7382 - val_loss: 0.5632 - val_accuracy: 0.8189 - val_categorical_accuracy: 0.8189 - val_auc_2: 0.9873 - val_precision_2: 0.8678 - val_recall_2: 0.7797 - val_true_positives_2: 1313.0000 - val_true_negatives_2: 41900.0000 - val_false_positives_2: 200.0000 - val_false_negatives_2: 371.0000 - val_cohen_kappa: 0.8110 - val_f1_score: 0.8093 - lr: 0.0010
# Epoch 9/30
# 832/831 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.7706 - categorical_accuracy: 0.7706 - auc_2: 0.9826 - precision_2: 0.8421 - recall_2: 0.7053 - true_positives_2: 9385.0000 - true_negatives_2: 330915.0000 - false_positives_2: 1760.0000 - false_negatives_2: 3922.0000 - cohen_kappa: 0.7608 - f1_score: 0.7688
# Epoch 9: val_accuracy did not improve from 0.81888
# 831/831 [==============================] - 226s 271ms/step - loss: 0.7191 - accuracy: 0.7706 - categorical_accuracy: 0.7706 - auc_2: 0.9826 - precision_2: 0.8421 - recall_2: 0.7053 - true_positives_2: 9385.0000 - true_negatives_2: 330915.0000 - false_positives_2: 1760.0000 - false_negatives_2: 3922.0000 - cohen_kappa: 0.7608 - f1_score: 0.7688 - val_loss: 0.5903 - val_accuracy: 0.8082 - val_categorical_accuracy: 0.8082 - val_auc_2: 0.9884 - val_precision_2: 0.8788 - val_recall_2: 0.7536 - val_true_positives_2: 1269.0000 - val_true_negatives_2: 41925.0000 - val_false_positives_2: 175.0000 - val_false_negatives_2: 415.0000 - val_cohen_kappa: 0.7999 - val_f1_score: 0.8004 - lr: 0.0010
# Epoch 10/30
# 832/831 [==============================] - ETA: 0s - loss: 0.6534 - accuracy: 0.7853 - categorical_accuracy: 0.7853 - auc_2: 0.9860 - precision_2: 0.8494 - recall_2: 0.7306 - true_positives_2: 9722.0000 - true_negatives_2: 330951.0000 - false_positives_2: 1724.0000 - false_negatives_2: 3585.0000 - cohen_kappa: 0.7762 - f1_score: 0.7830
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 10: val_accuracy improved from 0.81888 to 0.82363, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 228s 274ms/step - loss: 0.6534 - accuracy: 0.7853 - categorical_accuracy: 0.7853 - auc_2: 0.9860 - precision_2: 0.8494 - recall_2: 0.7306 - true_positives_2: 9722.0000 - true_negatives_2: 330951.0000 - false_positives_2: 1724.0000 - false_negatives_2: 3585.0000 - cohen_kappa: 0.7762 - f1_score: 0.7830 - val_loss: 0.5212 - val_accuracy: 0.8236 - val_categorical_accuracy: 0.8236 - val_auc_2: 0.9923 - val_precision_2: 0.8807 - val_recall_2: 0.7803 - val_true_positives_2: 1314.0000 - val_true_negatives_2: 41922.0000 - val_false_positives_2: 178.0000 - val_false_negatives_2: 370.0000 - val_cohen_kappa: 0.8162 - val_f1_score: 0.8215 - lr: 0.0010
# Epoch 11/30
# 832/831 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8965 - categorical_accuracy: 0.8965 - auc_2: 0.9965 - precision_2: 0.9222 - recall_2: 0.8762 - true_positives_2: 11659.0000 - true_negatives_2: 331692.0000 - false_positives_2: 983.0000 - false_negatives_2: 1648.0000 - cohen_kappa: 0.8921 - f1_score: 0.8945
# Epoch 11: val_accuracy improved from 0.82363 to 0.92102, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 232s 278ms/step - loss: 0.2898 - accuracy: 0.8965 - categorical_accuracy: 0.8965 - auc_2: 0.9965 - precision_2: 0.9222 - recall_2: 0.8762 - true_positives_2: 11659.0000 - true_negatives_2: 331692.0000 - false_positives_2: 983.0000 - false_negatives_2: 1648.0000 - cohen_kappa: 0.8921 - f1_score: 0.8945 - val_loss: 0.2163 - val_accuracy: 0.9210 - val_categorical_accuracy: 0.9210 - val_auc_2: 0.9979 - val_precision_2: 0.9331 - val_recall_2: 0.9115 - val_true_positives_2: 1535.0000 - val_true_negatives_2: 41990.0000 - val_false_positives_2: 110.0000 - val_false_negatives_2: 149.0000 - val_cohen_kappa: 0.9176 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 12/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9268 - categorical_accuracy: 0.9268 - auc_2: 0.9981 - precision_2: 0.9408 - recall_2: 0.9155 - true_positives_2: 12183.0000 - true_negatives_2: 331909.0000 - false_positives_2: 766.0000 - false_negatives_2: 1124.0000 - cohen_kappa: 0.9237 - f1_score: 0.9249
# Epoch 12: val_accuracy improved from 0.92102 to 0.94537, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 222s 267ms/step - loss: 0.1919 - accuracy: 0.9268 - categorical_accuracy: 0.9268 - auc_2: 0.9981 - precision_2: 0.9408 - recall_2: 0.9155 - true_positives_2: 12183.0000 - true_negatives_2: 331909.0000 - false_positives_2: 766.0000 - false_negatives_2: 1124.0000 - cohen_kappa: 0.9237 - f1_score: 0.9249 - val_loss: 0.1601 - val_accuracy: 0.9454 - val_categorical_accuracy: 0.9454 - val_auc_2: 0.9986 - val_precision_2: 0.9536 - val_recall_2: 0.9388 - val_true_positives_2: 1581.0000 - val_true_negatives_2: 42023.0000 - val_false_positives_2: 77.0000 - val_false_negatives_2: 103.0000 - val_cohen_kappa: 0.9430 - val_f1_score: 0.9388 - lr: 1.0000e-04
# Epoch 13/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9362 - categorical_accuracy: 0.9362 - auc_2: 0.9986 - precision_2: 0.9456 - recall_2: 0.9286 - true_positives_2: 12357.0000 - true_negatives_2: 331964.0000 - false_positives_2: 711.0000 - false_negatives_2: 950.0000 - cohen_kappa: 0.9334 - f1_score: 0.9337
# Epoch 13: val_accuracy did not improve from 0.94537
# 831/831 [==============================] - 228s 274ms/step - loss: 0.1658 - accuracy: 0.9362 - categorical_accuracy: 0.9362 - auc_2: 0.9986 - precision_2: 0.9456 - recall_2: 0.9286 - true_positives_2: 12357.0000 - true_negatives_2: 331964.0000 - false_positives_2: 711.0000 - false_negatives_2: 950.0000 - cohen_kappa: 0.9334 - f1_score: 0.9337 - val_loss: 0.1741 - val_accuracy: 0.9359 - val_categorical_accuracy: 0.9359 - val_auc_2: 0.9968 - val_precision_2: 0.9457 - val_recall_2: 0.9305 - val_true_positives_2: 1567.0000 - val_true_negatives_2: 42010.0000 - val_false_positives_2: 90.0000 - val_false_negatives_2: 117.0000 - val_cohen_kappa: 0.9331 - val_f1_score: 0.9293 - lr: 1.0000e-04
# Epoch 14/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9478 - categorical_accuracy: 0.9478 - auc_2: 0.9988 - precision_2: 0.9542 - recall_2: 0.9412 - true_positives_2: 12525.0000 - true_negatives_2: 332074.0000 - false_positives_2: 601.0000 - false_negatives_2: 782.0000 - cohen_kappa: 0.9455 - f1_score: 0.9454
# Epoch 14: val_accuracy did not improve from 0.94537
# 831/831 [==============================] - 223s 268ms/step - loss: 0.1370 - accuracy: 0.9478 - categorical_accuracy: 0.9478 - auc_2: 0.9988 - precision_2: 0.9542 - recall_2: 0.9412 - true_positives_2: 12525.0000 - true_negatives_2: 332074.0000 - false_positives_2: 601.0000 - false_negatives_2: 782.0000 - cohen_kappa: 0.9455 - f1_score: 0.9454 - val_loss: 0.1450 - val_accuracy: 0.9436 - val_categorical_accuracy: 0.9436 - val_auc_2: 0.9975 - val_precision_2: 0.9480 - val_recall_2: 0.9418 - val_true_positives_2: 1586.0000 - val_true_negatives_2: 42013.0000 - val_false_positives_2: 87.0000 - val_false_negatives_2: 98.0000 - val_cohen_kappa: 0.9412 - val_f1_score: 0.9393 - lr: 1.0000e-04
# Epoch 15/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9475 - categorical_accuracy: 0.9475 - auc_2: 0.9991 - precision_2: 0.9547 - recall_2: 0.9414 - true_positives_2: 12527.0000 - true_negatives_2: 332081.0000 - false_positives_2: 594.0000 - false_negatives_2: 780.0000 - cohen_kappa: 0.9453 - f1_score: 0.9450
# Epoch 15: val_accuracy improved from 0.94537 to 0.94715, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 225s 270ms/step - loss: 0.1336 - accuracy: 0.9475 - categorical_accuracy: 0.9475 - auc_2: 0.9991 - precision_2: 0.9547 - recall_2: 0.9414 - true_positives_2: 12527.0000 - true_negatives_2: 332081.0000 - false_positives_2: 594.0000 - false_negatives_2: 780.0000 - cohen_kappa: 0.9453 - f1_score: 0.9450 - val_loss: 0.1390 - val_accuracy: 0.9471 - val_categorical_accuracy: 0.9471 - val_auc_2: 0.9982 - val_precision_2: 0.9504 - val_recall_2: 0.9436 - val_true_positives_2: 1589.0000 - val_true_negatives_2: 42017.0000 - val_false_positives_2: 83.0000 - val_false_negatives_2: 95.0000 - val_cohen_kappa: 0.9449 - val_f1_score: 0.9425 - lr: 1.0000e-04
# Epoch 16/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9552 - categorical_accuracy: 0.9552 - auc_2: 0.9993 - precision_2: 0.9592 - recall_2: 0.9515 - true_positives_2: 12661.0000 - true_negatives_2: 332136.0000 - false_positives_2: 539.0000 - false_negatives_2: 646.0000 - cohen_kappa: 0.9533 - f1_score: 0.9531
# Epoch 16: val_accuracy improved from 0.94715 to 0.95012, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 225s 271ms/step - loss: 0.1126 - accuracy: 0.9552 - categorical_accuracy: 0.9552 - auc_2: 0.9993 - precision_2: 0.9592 - recall_2: 0.9515 - true_positives_2: 12661.0000 - true_negatives_2: 332136.0000 - false_positives_2: 539.0000 - false_negatives_2: 646.0000 - cohen_kappa: 0.9533 - f1_score: 0.9531 - val_loss: 0.1297 - val_accuracy: 0.9501 - val_categorical_accuracy: 0.9501 - val_auc_2: 0.9979 - val_precision_2: 0.9551 - val_recall_2: 0.9471 - val_true_positives_2: 1595.0000 - val_true_negatives_2: 42025.0000 - val_false_positives_2: 75.0000 - val_false_negatives_2: 89.0000 - val_cohen_kappa: 0.9480 - val_f1_score: 0.9460 - lr: 1.0000e-04
# Epoch 17/30
# 832/831 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9562 - categorical_accuracy: 0.9562 - auc_2: 0.9993 - precision_2: 0.9595 - recall_2: 0.9535 - true_positives_2: 12688.0000 - true_negatives_2: 332140.0000 - false_positives_2: 535.0000 - false_negatives_2: 619.0000 - cohen_kappa: 0.9543 - f1_score: 0.9535
# Epoch 17: val_accuracy did not improve from 0.95012
# 831/831 [==============================] - 223s 269ms/step - loss: 0.1055 - accuracy: 0.9562 - categorical_accuracy: 0.9562 - auc_2: 0.9993 - precision_2: 0.9595 - recall_2: 0.9535 - true_positives_2: 12688.0000 - true_negatives_2: 332140.0000 - false_positives_2: 535.0000 - false_negatives_2: 619.0000 - cohen_kappa: 0.9543 - f1_score: 0.9535 - val_loss: 0.1306 - val_accuracy: 0.9466 - val_categorical_accuracy: 0.9466 - val_auc_2: 0.9982 - val_precision_2: 0.9487 - val_recall_2: 0.9442 - val_true_positives_2: 1590.0000 - val_true_negatives_2: 42014.0000 - val_false_positives_2: 86.0000 - val_false_negatives_2: 94.0000 - val_cohen_kappa: 0.9442 - val_f1_score: 0.9418 - lr: 1.0000e-04
# Epoch 18/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9593 - categorical_accuracy: 0.9593 - auc_2: 0.9994 - precision_2: 0.9624 - recall_2: 0.9567 - true_positives_2: 12731.0000 - true_negatives_2: 332177.0000 - false_positives_2: 498.0000 - false_negatives_2: 576.0000 - cohen_kappa: 0.9576 - f1_score: 0.9564
# Epoch 18: val_accuracy improved from 0.95012 to 0.95071, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 228s 274ms/step - loss: 0.0990 - accuracy: 0.9593 - categorical_accuracy: 0.9593 - auc_2: 0.9994 - precision_2: 0.9624 - recall_2: 0.9567 - true_positives_2: 12731.0000 - true_negatives_2: 332177.0000 - false_positives_2: 498.0000 - false_negatives_2: 576.0000 - cohen_kappa: 0.9576 - f1_score: 0.9564 - val_loss: 0.1217 - val_accuracy: 0.9507 - val_categorical_accuracy: 0.9507 - val_auc_2: 0.9986 - val_precision_2: 0.9544 - val_recall_2: 0.9454 - val_true_positives_2: 1592.0000 - val_true_negatives_2: 42024.0000 - val_false_positives_2: 76.0000 - val_false_negatives_2: 92.0000 - val_cohen_kappa: 0.9486 - val_f1_score: 0.9454 - lr: 1.0000e-04
# Epoch 19/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9615 - categorical_accuracy: 0.9615 - auc_2: 0.9994 - precision_2: 0.9652 - recall_2: 0.9597 - true_positives_2: 12771.0000 - true_negatives_2: 332214.0000 - false_positives_2: 461.0000 - false_negatives_2: 536.0000 - cohen_kappa: 0.9599 - f1_score: 0.9590
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 19: val_accuracy improved from 0.95071 to 0.95784, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 228s 274ms/step - loss: 0.0905 - accuracy: 0.9615 - categorical_accuracy: 0.9615 - auc_2: 0.9994 - precision_2: 0.9652 - recall_2: 0.9597 - true_positives_2: 12771.0000 - true_negatives_2: 332214.0000 - false_positives_2: 461.0000 - false_negatives_2: 536.0000 - cohen_kappa: 0.9599 - f1_score: 0.9590 - val_loss: 0.1007 - val_accuracy: 0.9578 - val_categorical_accuracy: 0.9578 - val_auc_2: 0.9989 - val_precision_2: 0.9600 - val_recall_2: 0.9549 - val_true_positives_2: 1608.0000 - val_true_negatives_2: 42033.0000 - val_false_positives_2: 67.0000 - val_false_negatives_2: 76.0000 - val_cohen_kappa: 0.9560 - val_f1_score: 0.9529 - lr: 1.0000e-04
# Epoch 20/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9708 - categorical_accuracy: 0.9708 - auc_2: 0.9997 - precision_2: 0.9729 - recall_2: 0.9687 - true_positives_2: 12891.0000 - true_negatives_2: 332316.0000 - false_positives_2: 359.0000 - false_negatives_2: 416.0000 - cohen_kappa: 0.9696 - f1_score: 0.9682
# Epoch 20: val_accuracy did not improve from 0.95784
# 831/831 [==============================] - 234s 282ms/step - loss: 0.0683 - accuracy: 0.9708 - categorical_accuracy: 0.9708 - auc_2: 0.9997 - precision_2: 0.9729 - recall_2: 0.9687 - true_positives_2: 12891.0000 - true_negatives_2: 332316.0000 - false_positives_2: 359.0000 - false_negatives_2: 416.0000 - cohen_kappa: 0.9696 - f1_score: 0.9682 - val_loss: 0.0959 - val_accuracy: 0.9555 - val_categorical_accuracy: 0.9555 - val_auc_2: 0.9995 - val_precision_2: 0.9589 - val_recall_2: 0.9549 - val_true_positives_2: 1608.0000 - val_true_negatives_2: 42031.0000 - val_false_positives_2: 69.0000 - val_false_negatives_2: 76.0000 - val_cohen_kappa: 0.9535 - val_f1_score: 0.9511 - lr: 1.0000e-05
# Epoch 21/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc_2: 0.9997 - precision_2: 0.9766 - recall_2: 0.9741 - true_positives_2: 12962.0000 - true_negatives_2: 332365.0000 - false_positives_2: 310.0000 - false_negatives_2: 345.0000 - cohen_kappa: 0.9743 - f1_score: 0.9727
# Epoch 21: val_accuracy improved from 0.95784 to 0.95843, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 234s 281ms/step - loss: 0.0582 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc_2: 0.9997 - precision_2: 0.9766 - recall_2: 0.9741 - true_positives_2: 12962.0000 - true_negatives_2: 332365.0000 - false_positives_2: 310.0000 - false_negatives_2: 345.0000 - cohen_kappa: 0.9743 - f1_score: 0.9727 - val_loss: 0.0930 - val_accuracy: 0.9584 - val_categorical_accuracy: 0.9584 - val_auc_2: 0.9995 - val_precision_2: 0.9590 - val_recall_2: 0.9572 - val_true_positives_2: 1612.0000 - val_true_negatives_2: 42031.0000 - val_false_positives_2: 69.0000 - val_false_negatives_2: 72.0000 - val_cohen_kappa: 0.9566 - val_f1_score: 0.9539 - lr: 1.0000e-05
# Epoch 22/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9760 - categorical_accuracy: 0.9760 - auc_2: 0.9999 - precision_2: 0.9773 - recall_2: 0.9753 - true_positives_2: 12978.0000 - true_negatives_2: 332373.0000 - false_positives_2: 302.0000 - false_negatives_2: 329.0000 - cohen_kappa: 0.9750 - f1_score: 0.9736
# Epoch 22: val_accuracy did not improve from 0.95843
# 831/831 [==============================] - 228s 274ms/step - loss: 0.0522 - accuracy: 0.9760 - categorical_accuracy: 0.9760 - auc_2: 0.9999 - precision_2: 0.9773 - recall_2: 0.9753 - true_positives_2: 12978.0000 - true_negatives_2: 332373.0000 - false_positives_2: 302.0000 - false_negatives_2: 329.0000 - cohen_kappa: 0.9750 - f1_score: 0.9736 - val_loss: 0.0938 - val_accuracy: 0.9584 - val_categorical_accuracy: 0.9584 - val_auc_2: 0.9995 - val_precision_2: 0.9583 - val_recall_2: 0.9561 - val_true_positives_2: 1610.0000 - val_true_negatives_2: 42030.0000 - val_false_positives_2: 70.0000 - val_false_negatives_2: 74.0000 - val_cohen_kappa: 0.9566 - val_f1_score: 0.9545 - lr: 1.0000e-05
# Epoch 23/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9769 - categorical_accuracy: 0.9769 - auc_2: 0.9998 - precision_2: 0.9777 - recall_2: 0.9759 - true_positives_2: 12986.0000 - true_negatives_2: 332379.0000 - false_positives_2: 296.0000 - false_negatives_2: 321.0000 - cohen_kappa: 0.9759 - f1_score: 0.9746
# Epoch 23: val_accuracy did not improve from 0.95843
# 831/831 [==============================] - 228s 275ms/step - loss: 0.0504 - accuracy: 0.9769 - categorical_accuracy: 0.9769 - auc_2: 0.9998 - precision_2: 0.9777 - recall_2: 0.9759 - true_positives_2: 12986.0000 - true_negatives_2: 332379.0000 - false_positives_2: 296.0000 - false_negatives_2: 321.0000 - cohen_kappa: 0.9759 - f1_score: 0.9746 - val_loss: 0.0896 - val_accuracy: 0.9584 - val_categorical_accuracy: 0.9584 - val_auc_2: 0.9995 - val_precision_2: 0.9595 - val_recall_2: 0.9572 - val_true_positives_2: 1612.0000 - val_true_negatives_2: 42032.0000 - val_false_positives_2: 68.0000 - val_false_negatives_2: 72.0000 - val_cohen_kappa: 0.9566 - val_f1_score: 0.9536 - lr: 1.0000e-05
# Epoch 24/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9803 - categorical_accuracy: 0.9803 - auc_2: 0.9998 - precision_2: 0.9810 - recall_2: 0.9797 - true_positives_2: 13037.0000 - true_negatives_2: 332422.0000 - false_positives_2: 253.0000 - false_negatives_2: 270.0000 - cohen_kappa: 0.9795 - f1_score: 0.9781
# Epoch 24: val_accuracy improved from 0.95843 to 0.95903, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 227s 273ms/step - loss: 0.0445 - accuracy: 0.9803 - categorical_accuracy: 0.9803 - auc_2: 0.9998 - precision_2: 0.9810 - recall_2: 0.9797 - true_positives_2: 13037.0000 - true_negatives_2: 332422.0000 - false_positives_2: 253.0000 - false_negatives_2: 270.0000 - cohen_kappa: 0.9795 - f1_score: 0.9781 - val_loss: 0.0920 - val_accuracy: 0.9590 - val_categorical_accuracy: 0.9590 - val_auc_2: 0.9995 - val_precision_2: 0.9595 - val_recall_2: 0.9578 - val_true_positives_2: 1613.0000 - val_true_negatives_2: 42032.0000 - val_false_positives_2: 68.0000 - val_false_negatives_2: 71.0000 - val_cohen_kappa: 0.9572 - val_f1_score: 0.9542 - lr: 1.0000e-05
# Epoch 25/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9806 - categorical_accuracy: 0.9806 - auc_2: 0.9999 - precision_2: 0.9813 - recall_2: 0.9799 - true_positives_2: 13040.0000 - true_negatives_2: 332427.0000 - false_positives_2: 248.0000 - false_negatives_2: 267.0000 - cohen_kappa: 0.9798 - f1_score: 0.9785
# Epoch 25: val_accuracy improved from 0.95903 to 0.96021, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 222s 266ms/step - loss: 0.0449 - accuracy: 0.9806 - categorical_accuracy: 0.9806 - auc_2: 0.9999 - precision_2: 0.9813 - recall_2: 0.9799 - true_positives_2: 13040.0000 - true_negatives_2: 332427.0000 - false_positives_2: 248.0000 - false_negatives_2: 267.0000 - cohen_kappa: 0.9798 - f1_score: 0.9785 - val_loss: 0.0925 - val_accuracy: 0.9602 - val_categorical_accuracy: 0.9602 - val_auc_2: 0.9995 - val_precision_2: 0.9613 - val_recall_2: 0.9590 - val_true_positives_2: 1615.0000 - val_true_negatives_2: 42035.0000 - val_false_positives_2: 65.0000 - val_false_negatives_2: 69.0000 - val_cohen_kappa: 0.9585 - val_f1_score: 0.9550 - lr: 1.0000e-05
# Epoch 26/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9796 - categorical_accuracy: 0.9796 - auc_2: 0.9998 - precision_2: 0.9805 - recall_2: 0.9791 - true_positives_2: 13029.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 278.0000 - cohen_kappa: 0.9787 - f1_score: 0.9773
# Epoch 26: val_accuracy improved from 0.96021 to 0.96081, saving model to Best_DenseNet201_v23.h5
# 831/831 [==============================] - 229s 275ms/step - loss: 0.0448 - accuracy: 0.9796 - categorical_accuracy: 0.9796 - auc_2: 0.9998 - precision_2: 0.9805 - recall_2: 0.9791 - true_positives_2: 13029.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 278.0000 - cohen_kappa: 0.9787 - f1_score: 0.9773 - val_loss: 0.0919 - val_accuracy: 0.9608 - val_categorical_accuracy: 0.9608 - val_auc_2: 0.9989 - val_precision_2: 0.9619 - val_recall_2: 0.9602 - val_true_positives_2: 1617.0000 - val_true_negatives_2: 42036.0000 - val_false_positives_2: 64.0000 - val_false_negatives_2: 67.0000 - val_cohen_kappa: 0.9591 - val_f1_score: 0.9568 - lr: 1.0000e-05
# Epoch 27/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9789 - categorical_accuracy: 0.9789 - auc_2: 1.0000 - precision_2: 0.9791 - recall_2: 0.9783 - true_positives_2: 13018.0000 - true_negatives_2: 332397.0000 - false_positives_2: 278.0000 - false_negatives_2: 289.0000 - cohen_kappa: 0.9780 - f1_score: 0.9763
# Epoch 27: val_accuracy did not improve from 0.96081
# 831/831 [==============================] - 223s 268ms/step - loss: 0.0447 - accuracy: 0.9789 - categorical_accuracy: 0.9789 - auc_2: 1.0000 - precision_2: 0.9791 - recall_2: 0.9783 - true_positives_2: 13018.0000 - true_negatives_2: 332397.0000 - false_positives_2: 278.0000 - false_negatives_2: 289.0000 - cohen_kappa: 0.9780 - f1_score: 0.9763 - val_loss: 0.0891 - val_accuracy: 0.9596 - val_categorical_accuracy: 0.9596 - val_auc_2: 0.9996 - val_precision_2: 0.9613 - val_recall_2: 0.9590 - val_true_positives_2: 1615.0000 - val_true_negatives_2: 42035.0000 - val_false_positives_2: 65.0000 - val_false_negatives_2: 69.0000 - val_cohen_kappa: 0.9579 - val_f1_score: 0.9555 - lr: 1.0000e-05
# Epoch 28/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9801 - categorical_accuracy: 0.9801 - auc_2: 0.9998 - precision_2: 0.9804 - recall_2: 0.9796 - true_positives_2: 13035.0000 - true_negatives_2: 332414.0000 - false_positives_2: 261.0000 - false_negatives_2: 272.0000 - cohen_kappa: 0.9792 - f1_score: 0.9778
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 28: val_accuracy did not improve from 0.96081
# 831/831 [==============================] - 223s 268ms/step - loss: 0.0423 - accuracy: 0.9801 - categorical_accuracy: 0.9801 - auc_2: 0.9998 - precision_2: 0.9804 - recall_2: 0.9796 - true_positives_2: 13035.0000 - true_negatives_2: 332414.0000 - false_positives_2: 261.0000 - false_negatives_2: 272.0000 - cohen_kappa: 0.9792 - f1_score: 0.9778 - val_loss: 0.0934 - val_accuracy: 0.9596 - val_categorical_accuracy: 0.9596 - val_auc_2: 0.9989 - val_precision_2: 0.9613 - val_recall_2: 0.9590 - val_true_positives_2: 1615.0000 - val_true_negatives_2: 42035.0000 - val_false_positives_2: 65.0000 - val_false_negatives_2: 69.0000 - val_cohen_kappa: 0.9579 - val_f1_score: 0.9545 - lr: 1.0000e-05
# Epoch 29/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9799 - categorical_accuracy: 0.9799 - auc_2: 0.9999 - precision_2: 0.9805 - recall_2: 0.9792 - true_positives_2: 13030.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 277.0000 - cohen_kappa: 0.9791 - f1_score: 0.9773
# Epoch 29: val_accuracy did not improve from 0.96081
# 831/831 [==============================] - 221s 265ms/step - loss: 0.0423 - accuracy: 0.9799 - categorical_accuracy: 0.9799 - auc_2: 0.9999 - precision_2: 0.9805 - recall_2: 0.9792 - true_positives_2: 13030.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 277.0000 - cohen_kappa: 0.9791 - f1_score: 0.9773 - val_loss: 0.0923 - val_accuracy: 0.9602 - val_categorical_accuracy: 0.9602 - val_auc_2: 0.9993 - val_precision_2: 0.9602 - val_recall_2: 0.9596 - val_true_positives_2: 1616.0000 - val_true_negatives_2: 42033.0000 - val_false_positives_2: 67.0000 - val_false_negatives_2: 68.0000 - val_cohen_kappa: 0.9585 - val_f1_score: 0.9551 - lr: 1.0000e-05
# Epoch 30/30
# 832/831 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9799 - categorical_accuracy: 0.9799 - auc_2: 0.9999 - precision_2: 0.9805 - recall_2: 0.9795 - true_positives_2: 13034.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 273.0000 - cohen_kappa: 0.9791 - f1_score: 0.9772
# Epoch 30: val_accuracy did not improve from 0.96081
# 831/831 [==============================] - 230s 277ms/step - loss: 0.0432 - accuracy: 0.9799 - categorical_accuracy: 0.9799 - auc_2: 0.9999 - precision_2: 0.9805 - recall_2: 0.9795 - true_positives_2: 13034.0000 - true_negatives_2: 332416.0000 - false_positives_2: 259.0000 - false_negatives_2: 273.0000 - cohen_kappa: 0.9791 - f1_score: 0.9772 - val_loss: 0.0937 - val_accuracy: 0.9572 - val_categorical_accuracy: 0.9572 - val_auc_2: 0.9989 - val_precision_2: 0.9584 - val_recall_2: 0.9572 - val_true_positives_2: 1612.0000 - val_true_negatives_2: 42030.0000 - val_false_positives_2: 70.0000 - val_false_negatives_2: 72.0000 - val_cohen_kappa: 0.9554 - val_f1_score: 0.9527 - lr: 1.0000e-05

# %%
evaluate_(final_model, generator_test)
# Out:
# 106/106 [==============================] - 21s 196ms/step - loss: 0.0937 - accuracy: 0.9572 - categorical_accuracy: 0.9572 - auc_2: 0.9989 - precision_2: 0.9584 - recall_2: 0.9572 - true_positives_2: 1612.0000 - true_negatives_2: 42030.0000 - false_positives_2: 70.0000 - false_negatives_2: 72.0000 - cohen_kappa: 0.9554 - f1_score: 0.9527
# 106/106 [==============================] - 18s 162ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        61
#            1       0.98      0.95      0.97        60
#            2       0.65      0.67      0.66        60
#            3       0.97      0.92      0.94        62
#            4       1.00      0.94      0.97        53
#            5       0.97      1.00      0.98        63
#            6       1.00      1.00      1.00        62
#            7       0.58      0.56      0.57        50
#            8       1.00      0.98      0.99        62
#            9       0.97      1.00      0.98        62
#           10       0.99      0.96      0.97       100
#           11       0.97      0.95      0.96        60
#           12       0.94      1.00      0.97        45
#           13       1.00      1.00      1.00        74
#           14       0.99      0.97      0.98        86
#           15       0.97      0.97      0.97        62
#           16       1.00      1.00      1.00        38
#           17       0.96      1.00      0.98       119
#           18       1.00      0.97      0.98        60
#           19       0.96      1.00      0.98        72
#           20       0.99      0.99      0.99        81
#           21       0.98      1.00      0.99        42
#           22       1.00      1.00      1.00        63
#           23       1.00      0.97      0.99        36
#           24       0.95      0.98      0.97        62
#           25       1.00      0.99      0.99        89
#
#     accuracy                           0.96      1684
#    macro avg       0.95      0.95      0.95      1684
# weighted avg       0.96      0.96      0.96      1684
# /tmp/ipykernel_32/2485669865.py:45: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# !pip install --upgrade scipy scikit-image

# %%
image_size = 128
batch_size = 8

train_dir = r"/kaggle/input/mango-leaf/mango-prepo/train"
val_dir = r"/kaggle/input/mango-leaf/mango-prepo/val"
test_dir = r"/kaggle/input/mango-leaf/mango-prepo/test"


datagen_train = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1,
                                  horizontal_flip=True,  vertical_flip=False)
datagen_test = ImageDataGenerator(rescale=1./255)

train_generator = datagen_train.flow_from_directory(directory=train_dir, target_size=(image_size, image_size),
                                                    batch_size=batch_size, shuffle=True)
val_generator = datagen_test.flow_from_directory(directory=val_dir, target_size=(image_size, image_size),
                                                  batch_size=batch_size, shuffle=False)
test_generator = datagen_test.flow_from_directory(directory=test_dir, target_size=(image_size, image_size),
                                                  batch_size=batch_size, shuffle=False)

#Define the number of classes in your dataset
num_classes = train_generator.num_classes

# %%
from tensorflow.keras.layers import Layer, Attention
import numpy as np

# %%
class LinearAttention(Layer):
    def __init__(self, units):
        super(LinearAttention, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.W_q = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)
        self.W_k = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)
        self.W_v = self.add_weight(shape=(input_shape[-1], self.units), initializer='uniform', trainable=True)

    def call(self, inputs):
        Q = tf.matmul(inputs, self.W_q)
        K = tf.matmul(inputs, self.W_k)
        V = tf.matmul(inputs, self.W_v)

        attn_scores = tf.matmul(Q, K, transpose_b=True)
        attn_scores = tf.nn.softmax(attn_scores / tf.math.sqrt(tf.cast(self.units, tf.float32)), axis=-1)
        output = tf.matmul(attn_scores, V)

        return output

# %%
# Define your model function with attention
def modelfunction_with_attention(base):
    x = base.output

    # Add Self-Attention Layer
    att_output = LinearAttention(128)(x)

    # Add more layers if needed
    x = tf.keras.layers.GlobalAveragePooling2D()(att_output)
    x = tf.keras.layers.Dropout(0.4)(x)
    predictions = tf.keras.layers.Dense(units=num_classes, activation='softmax', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.02, l2=0.02))(x)
    model = Model(inputs=base.input, outputs=predictions)
    return model

# %%
def modelfunction(base):
    x = base.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    predictions = tf.keras.layers.Dense(units=num_classes, activation='softmax', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.02, l2=0.02))(x)
    model = Model(inputs=base.input, outputs=predictions)
    return model

def get_callbacks(weight):
    checkpoint = ModelCheckpoint(weight, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.2, min_lr=0.0002)
    callbacks = [checkpoint, learning_rate_reduction]
    return callbacks

def evaluate(model, generator_test):
    model.evaluate(generator_test)

    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)

    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()

def model_training(base, weight, epochs):
    model = modelfunction(base)
    print("\n\n\n-------------------- Model Initialized --------------------")

    callbacks = get_callbacks(weight)
    metrics = ['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(),
               tfa.metrics.CohenKappa(num_classes=num_classes), tfa.metrics.F1Score(num_classes=num_classes)]
    model.compile(tf.keras.optimizers.Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=metrics)

    history = model.fit(train_generator, steps_per_epoch=366 // batch_size,
                        validation_data=val_generator,  # Add this line
                        epochs=epochs, callbacks=callbacks)
    # Plotting accuracy and loss curves
    plt.figure(figsize=(12, 4))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

    print("\n\n\n-------------------- Evaluation --------------------")
    evaluate(model, val_generator)

    return model

# %%
# Create and train the model with attention
VGG19 = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_tensor=None, input_shape=None)
VGG19_model_with_attention = model_training(VGG19, 'VGG19_with_attention.h5', 10)

# %%
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries
import matplotlib.pyplot as plt
import random

# %%
from lime import lime_image

# %%
from skimage.segmentation import mark_boundaries
